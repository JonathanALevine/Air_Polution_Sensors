# %%
import openpyxl
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor

from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold

from matplotlib import pyplot as plt
import datetime
import math
import pandas as pd
from scipy import stats
import seaborn as sn

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

# Read in the dataframe
dataframe = pd.read_pickle('merged_dataset_elasped_time_hours_added.pkl')
dataframe = dataframe.dropna()

# Convert to numpy array
# Seperate the target 
# Remove the target from the DATA matrix
DATA = dataframe.to_numpy()
target = DATA[:,12].reshape(-1,1)
DATA = np.delete(DATA, 12, 1)
# Delete the dates
DATA = np.delete(DATA, 0, 1)
# Separate the elasped time (hours)
# Remove from the DATA matrix
hours = DATA[:,0]
DATA = np.delete(DATA, 0, 1)

# Display the dataframe
dataframe
# Out:
# <style>.container { width:90% !important; }</style>
#                dt_hour  elapsed_time_hours  e_series_pm  ambient_Temp_C_Mean  \
# 0      2015-11-07 1:00                 0.0     0.679598            -1.928276
# 1      2015-11-07 2:00                 1.0     0.501925            -2.192000
# 2      2015-11-07 3:00                 2.0     0.559391            -1.828172
# 3      2015-11-07 4:00                 3.0     0.564632            -1.751328
# 4      2015-11-07 5:00                 4.0     0.607770            -2.136534
# ...                ...                 ...          ...                  ...
# 12389  2017-04-26 3:00             12866.0     1.886483            -3.908121
# 12390  2017-04-26 4:00             12867.0     2.793138            -4.397569
# 12391  2017-04-26 5:00             12868.0     3.117776            -4.896259
# 12392  2017-04-26 6:00             12869.0     3.179569            -5.146069
# ...

# %%
dataframe_new = dataframe.drop(columns=['reference_pm'])
corrMatrix = dataframe_new.corr()
plt.subplots(figsize=(10,10))
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
DATA[:,0].reshape(-1,1)
# Out:
# array([[0.6795977009999999],
#        [0.501925287],
#        [0.559390805],
#        ...,
#        [3.117775862],
#        [3.179568966],
#        [2.679603448]], dtype=object)

# %%
linear_regression = LinearRegression().fit(DATA[:,0].reshape(-1,1), target)
# Plot the values graph with the regression line
plt.figure(figsize=(25,20))
plt.plot(DATA[:,0], target, 'o')
plt.plot(DATA[:,0], 
         linear_regression.predict(DATA[:,0].reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0][0], linear_regression.intercept_[0]),
         linewidth=3)
plt.xlabel('Predicted Concentration (ugm3)', fontsize=25)
plt.ylabel('Reference Concentration (ugm3)', fontsize=25)
plt.legend(loc='best', fontsize=25)

# %%
metrics.r2_score(target, linear_regression.predict(DATA[:,0].reshape(-1,1)))
# Out:
# 0.8242815958778367

# %%
# Split the data set into two halves, getting matrices a and b
A, B = np.split(np.delete(DATA, len(DATA)-1, 0), 2)
# Add the last odd row to b
B = np.vstack([B, DATA[:][len(DATA)-1]])
# Split the target
a, b = np.split(np.delete(target, len(target)-1, 0), 2)
b = np.vstack([b, target[:][len(target)-1]])
# Split the hours
a_hours, b_hours = np.split(np.delete(hours, len(hours)-1, 0), 2)
hours[:][len(hours)-1]
b_hours = np.append(b_hours, hours[:][len(hours)-1])

# %%
# Simple Linear Regression method
linear_regression = LinearRegression().fit(A, a)
print("Test set score: {:0.6f}".format(linear_regression.score(A, a)))
print('MAE: {:0.4f}'.format(metrics.mean_absolute_error(a, linear_regression.predict(A))))
R2 = metrics.r2_score(a, linear_regression.predict(A))
adjusted_R2 = 1 - ((1-R2**2)*(np.size(A[:,0],0)-1))/(np.size(A[:,0],0) - np.size(A[:0],1) - 1)
print('R2: {:0.4f}'.format(R2))
print('adjusted-R2: {:0.4f}'.format(adjusted_R2))
print('Estimator feature strengths: {}'.format(linear_regression.coef_))
# Out:
# Test set score: 0.778410
# MAE: 1.5166
# R2: 0.7784
# adjusted-R2: 0.6053
# Estimator feature strengths: [[ 5.89002018e-01  2.60853542e-02  2.75903725e-02  9.47352780e-03
#    5.61504708e-04  2.84725156e-03 -6.21833180e-01  7.89485942e-02
#    6.42858229e-01 -9.99736435e-02]]

# %%
# Calculate a regression line
linear_regression = LinearRegression().fit(elastic_net.predict(A).reshape(-1,1), a)
# Plot the values graph with the regression line
plt.figure(figsize=(25,20))
plt.plot(elastic_net.predict(A).reshape(-1,1), a, 'o')
plt.plot(elastic_net.predict(A), 
         linear_regression.predict(elastic_net.predict(A).reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0][0], linear_regression.intercept_[0]),
         linewidth=3)
plt.xlabel('Predicted Concentration (ugm3)', fontsize=25)
plt.ylabel('Reference Concentration (ugm3)', fontsize=25)
plt.legend(loc='best', fontsize=25)

# %%
print('MAE: {:0.4f}'.format(metrics.mean_absolute_error(b, elastic_net.predict(B))))
R2 = metrics.r2_score(b, elastic_net.predict(B))
adjusted_R2 = 1 - ((1-R2**2)*(np.size(B[:,0],0)-1))/(np.size(B[:,0],0) - np.size(B[:0],1) - 1)
print('R2: {:0.4f}'.format(R2))
print('adjusted-R2: {:0.4f}'.format(adjusted_R2))
print('Estimator feature strengths: {}'.format(elastic_net.coef_))
# Out:
# MAE: 1.8712
# R2: 0.8279
# adjusted-R2: 0.6849
# Estimator feature strengths: [ 5.88958517e-01  2.61427791e-02  2.76047433e-02  9.48109886e-03
#   5.65188700e-04  2.84887793e-03 -6.20700979e-01  6.32464058e-02
#   6.25577187e-01 -1.11008540e-01]

# %%
# Plot the time series graph
plt.figure(figsize=(25,20))
plt.plot(b_hours, b, 'o',label="Reference PM Sensor")
plt.plot(b_hours, elastic_net.predict(B), 'o',label="ElasticNet Regression")
plt.xlabel('Time (Hours)', fontsize=25)
plt.ylabel('PM Concentration (ugm3)', fontsize=25)
plt.legend(loc='best', fontsize=25)

# %%
# Calculate a regression line
linear_regression = LinearRegression().fit(elastic_net.predict(B).reshape(-1,1), b)
# Plot the values graph with the regression line
plt.figure(figsize=(25,20))
plt.plot(elastic_net.predict(B).reshape(-1,1), b, 'o')
plt.plot(elastic_net.predict(B), 
         linear_regression.predict(elastic_net.predict(B).reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0][0], linear_regression.intercept_[0]),
         linewidth=3)
plt.xlabel('Predicted Concentration (ugm3)', fontsize=25)
plt.ylabel('Reference Concentration (ugm3)', fontsize=25)
plt.legend(loc='best', fontsize=25)
