# %%
import openpyxl
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn import preprocessing

from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold

from matplotlib import pyplot as plt
import datetime
import math
import pandas as pd
from scipy import stats
import seaborn as sn

from sklearn.tree import export_text

import statsmodels.api as sm

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))

# Drops specific values in a dataframe
# if flag = 1, drops values less than 'val'
# if flag = 0, drops values greater than 'val'
def drop_values(dataframe, column, val, flag):
    if flag:
        return dataframe.drop(dataframe[column < val].index)
    else:
        return dataframe.drop(dataframe[column > val].index)
    
# GET THE EGG SENSORS WITH AIRPOINTER
dataframe = pd.read_pickle('EGG2_DATASET.pkl')
dataframe = dataframe.iloc[3:]
dataframe
# Out:
# <style>.container { width:98% !important; }</style>
#                      Temperature[degC]  Humidity[percent]  PM1.0[ug/m^3]  \
# Timestamp
# 2020-05-06 16:00:00          20.936500          19.845833       1.188333
# 2020-05-06 17:00:00          20.838500          19.497333       1.536667
# 2020-05-06 18:00:00          18.088000          21.523500       1.903333
# 2020-05-06 19:00:00          15.246833          25.020167       2.448333
# 2020-05-06 20:00:00          13.793333          23.878000       0.660000
# ...                                ...                ...            ...
# 2020-06-11 08:00:00          22.916833          46.543500       0.011667
# 2020-06-11 09:00:00          28.374500          33.868500       0.193333
# 2020-06-11 10:00:00          30.390500          31.093833       0.008333
# 2020-06-11 11:00:00          30.402000          30.781500       0.015000
# 2020-06-11 12:00:00          28.100652          33.646087       0.965217
#
#                      PM2.5[ug/m^3]  PM10.0[ug/m^3]    O3[ppb]     O3[V]  \
# Timestamp
# 2020-05-06 16:00:00       2.235000        2.576667  50.088667  1.426638
# 2020-05-06 17:00:00       2.705000        3.088333  49.248667  1.426650
# 2020-05-06 18:00:00       3.203333        3.665000  51.494000  1.426415
# 2020-05-06 19:00:00       3.898333        4.298333  53.309000  1.426180
# 2020-05-06 20:00:00       1.293333        1.510000  50.617667  1.426136
# ...                            ...             ...        ...       ...
# 2020-06-11 08:00:00       0.023333        0.076667  37.494833  1.427053
# 2020-06-11 09:00:00       0.210000        0.248333  45.627333  1.427341
# 2020-06-11 10:00:00       0.020000        0.061667  52.935500  1.427374
# 2020-06-11 11:00:00       0.121667        0.230000  54.036000  1.427351
# 2020-06-11 12:00:00       1.339130        1.478261  55.471522  1.427100
#
#                        NO2[ppb]    NO2[V]  Pressure[Pa]     NO     NO2  \
# Timestamp
# 2020-05-06 16:00:00  159.735500  1.416693  99177.978333  1.490   3.941
# 2020-05-06 17:00:00  146.279333  1.416790  99149.185000  1.910   5.132
# 2020-05-06 18:00:00  126.373333  1.416782  99160.285000  2.493   7.458
# 2020-05-06 19:00:00  115.848667  1.416693  99190.693333  1.458  10.777
# 2020-05-06 20:00:00   97.193000  1.416746  99246.608333  0.397   3.695
# ...                         ...       ...           ...    ...     ...
# 2020-06-11 08:00:00  101.751333  1.417265  99020.620000  1.155   2.578
# 2020-06-11 09:00:00   77.866167  1.417884  99172.726667  1.176   2.672
# 2020-06-11 10:00:00   74.693500  1.418105  99255.553333  1.290   2.521
# 2020-06-11 11:00:00   85.435333  1.418022  99336.821667  1.233   2.704
# 2020-06-11 12:00:00   94.126087  1.417729  99417.165217  1.215   2.831
#
#                         NOx      O3  PM10_conc  PM10-2.5_conc  PM2.5_conc  \
# Timestamp
# 2020-05-06 16:00:00   5.639  40.473     15.705         11.404       4.303
# 2020-05-06 17:00:00   6.875  40.592     19.672         15.035       4.628
# 2020-05-06 18:00:00   9.555  39.162     21.342         16.181       5.170
# 2020-05-06 19:00:00  12.126  35.057     16.456         11.442       5.010
# 2020-05-06 20:00:00   4.078  38.341     13.062          9.670       3.400
# ...                     ...     ...        ...            ...         ...
# 2020-06-11 08:00:00   3.717  12.515      9.557          8.350       1.206
# 2020-06-11 09:00:00   3.848  21.919      9.565          8.244       1.322
# 2020-06-11 10:00:00   3.767  22.186      8.287          6.954       1.334
# 2020-06-11 11:00:00   3.937  24.137      9.399          7.297       2.102
# 2020-06-11 12:00:00   4.046  25.151      9.657          6.841       2.816
#
#                      Air_Temperature  Relative_Humidity
# Timestamp
# 2020-05-06 16:00:00           12.375             27.602
# 2020-05-06 17:00:00           12.848             26.503
# 2020-05-06 18:00:00           12.150             27.662
# 2020-05-06 19:00:00           11.400             28.912
# 2020-05-06 20:00:00           10.556             26.898
# ...                              ...                ...
# 2020-06-11 08:00:00           17.117             60.513
# 2020-06-11 09:00:00           18.267             50.782
# 2020-06-11 10:00:00           19.047             50.624
# 2020-06-11 11:00:00           19.908             48.916
# 2020-06-11 12:00:00           20.396             47.914
#
# [861 rows x 19 columns]

# %%
corrMatrix = dataframe.corr()
plt.subplots(figsize=(15,15))
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
# ----------------------------- TEMPERATURE FROM CLUSTER vs. AIR_TEMPERATURE FROM AIRPOINTER ----------------------------------------
plt.figure(figsize=(15,10))
plt.plot(dataframe.index.to_series(), dataframe['Temperature[degC]'], 'o', label="EGG/CLUSTER")
plt.plot(dataframe.index.to_series(), dataframe['Air_Temperature'], 'o', label='AIRPOINTER')
plt.xlabel('Date (YYYY-MM-DD)', fontsize=15)
plt.ylabel('Temperature (degC)', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate a regression line
# Egg sensor
xValues = dataframe['Temperature[degC]'].to_numpy()
# Airpointer
yValues = dataframe['Air_Temperature'].to_numpy()
# Regression Line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('EGG/CLUSTER', fontsize=15)
plt.ylabel('AIRPOINTER', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate the R2 score
metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1)))
# Out:
# 0.9455714387102117

# %%
# ----------------------------- HUMIDITY FROM CLUSTER vs. HUMIDITY FROM AIRPOINTER ----------------------------------------
plt.figure(figsize=(15,10))
plt.plot(dataframe.index.to_series(), dataframe['Humidity[percent]'], 'o', label="EGG/CLUSTER")
plt.plot(dataframe.index.to_series(), dataframe['Relative_Humidity'], 'o', label='AIRPOINTER')
plt.xlabel('Date (YYYY-MM-DD)', fontsize=15)
plt.ylabel('Humidity[%]', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate a regression line
# Egg sensor
xValues = dataframe['Humidity[percent]'].to_numpy()
# Airpointer
yValues = dataframe['Relative_Humidity'].to_numpy()
# Regression Line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('EGG/CLUSTER', fontsize=15)
plt.ylabel('AIRPOINTER', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate the R2 score
metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1)))
# Out:
# 0.943639729422526

# %%
# ----------------------------- PM2.5 FROM CLUSTER vs. PM2.5 FROM AIRPOINTER ----------------------------------------
plt.figure(figsize=(15,10))
plt.plot(dataframe.index.to_series(), dataframe['PM2.5[ug/m^3]'], 'o', label="EGG/CLUSTER")
plt.plot(dataframe.index.to_series(), dataframe['PM2.5_conc'], 'o', label='AIRPOINTER')
plt.xlabel('Date (YYYY-MM-DD)', fontsize=15)
plt.ylabel('PM2.5[ug/m^3]', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate a regression line
# Egg sensor
xValues = dataframe['PM2.5[ug/m^3]'].to_numpy()
# Airpointer
yValues = dataframe['PM2.5_conc'].to_numpy()
# Regression Line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('EGG/CLUSTER', fontsize=15)
plt.ylabel('AIRPOINTER', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate the R2 score
metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1)))
# Out:
# 0.4970506609635349

# %%
# ----------------------------- PM10.0 FROM CLUSTER vs. PM10.0 FROM AIRPOINTER ----------------------------------------
plt.figure(figsize=(15,10))
plt.plot(dataframe.index.to_series(), dataframe['PM10.0[ug/m^3]'], 'o', label="EGG/CLUSTER")
plt.plot(dataframe.index.to_series(), dataframe['PM10_conc'], 'o', label='AIRPOINTER')
plt.xlabel('Date (YYYY-MM-DD)', fontsize=15)
plt.ylabel('PM10.0[ug/m^3]', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate a regression line
# Egg sensor
xValues = dataframe['PM10.0[ug/m^3]'].to_numpy()
# Airpointer
yValues = dataframe['PM10_conc'].to_numpy()
# Regression Line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('EGG/CLUSTER', fontsize=15)
plt.ylabel('AIRPOINTER', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate the R2 score
metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1)))
# Out:
# 0.313033957630968

# %%
# ----------------------------- O3 (OZONE) FROM CLUSTER vs. O3 (OZONE) FROM AIRPOINTER ----------------------------------------
plt.figure(figsize=(15,10))
plt.plot(dataframe.index.to_series(), dataframe['O3[ppb]'], 'o', label="EGG/CLUSTER")
plt.plot(dataframe.index.to_series(), dataframe['O3'], 'o', label='AIRPOINTER')
plt.xlabel('Date (YYYY-MM-DD)', fontsize=15)
plt.ylabel('O3[ppb]', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate a regression line
# Egg sensor
xValues = dataframe['O3[ppb]'].to_numpy()
# Airpointer
yValues = dataframe['O3'].to_numpy()
# Regression Line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('EGG/CLUSTER', fontsize=15)
plt.ylabel('AIRPOINTER', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate the R2 score
metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1)))
# Out:
# 0.16833134905437774

# %%
# ----------------------------- NO2 FROM CLUSTER vs. NO2 FROM AIRPOINTER ----------------------------------------
plt.figure(figsize=(15,10))
plt.plot(dataframe.index.to_series(), dataframe['NO2[ppb]'], 'o', label="EGG/CLUSTER")
plt.plot(dataframe.index.to_series(), dataframe['NO2'], 'o', label='AIRPOINTER')
plt.xlabel('Date (YYYY-MM-DD)', fontsize=15)
plt.ylabel('O3[ppb]', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate a regression line
# Egg sensor
xValues = dataframe['NO2[ppb]'].to_numpy()
# Airpointer
yValues = dataframe['O3'].to_numpy()
# Regression Line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('EGG/CLUSTER', fontsize=15)
plt.ylabel('AIRPOINTER', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate the R2 score
metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1)))
# Out:
# 0.00013092339152775967

# %%
# Calculate a regression line
# Egg sensor
xValues = dataframe['Temperature[degC]'].to_numpy()
# Airpointer
yValues = dataframe['NO2[V]'].to_numpy()
# Regression Line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('Temperature[degC]', fontsize=15)
plt.ylabel('NO2[V]', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate the R2 score
metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1)))
# Out:
# 0.879604711518778

# %%
# Calculate a regression line
# Egg sensor
xValues = dataframe['Temperature[degC]'].to_numpy()
# Airpointer
yValues = dataframe['O3[V]'].to_numpy()
# Regression Line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('Temperature[degC]', fontsize=15)
plt.ylabel('O3[V]', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate the R2 score
metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1)))
# Out:
# 0.9619404333537256

# %%
# Calculate a regression line
# Egg sensor
xValues = dataframe['NO2[V]'].to_numpy()
# Airpointer
yValues = dataframe['NO2'].to_numpy()
# Regression Line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('NO2[V]', fontsize=15)
plt.ylabel('NO2', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate the R2 score
metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1)))
# Out:
# 0.008549564283249156

# %%
dataframe.head()
# Out:
#                      Temperature[degC]  Humidity[percent]  PM1.0[ug/m^3]  \
# 2020-05-06 16:00:00          20.936500          19.845833       1.188333
# 2020-05-06 17:00:00          20.838500          19.497333       1.536667
# 2020-05-06 18:00:00          18.088000          21.523500       1.903333
# 2020-05-06 19:00:00          15.246833          25.020167       2.448333
# 2020-05-06 20:00:00          13.793333          23.878000       0.660000
#
#                      PM2.5[ug/m^3]  PM10.0[ug/m^3]    O3[ppb]     O3[V]  \
# 2020-05-06 16:00:00       2.235000        2.576667  50.088667  1.426638
# 2020-05-06 17:00:00       2.705000        3.088333  49.248667  1.426650
# 2020-05-06 18:00:00       3.203333        3.665000  51.494000  1.426415
# 2020-05-06 19:00:00       3.898333        4.298333  53.309000  1.426180
# 2020-05-06 20:00:00       1.293333        1.510000  50.617667  1.426136
#
#                        NO2[ppb]    NO2[V]  Pressure[Pa]     NO     NO2  \
# 2020-05-06 16:00:00  159.735500  1.416693  99177.978333  1.490   3.941
# 2020-05-06 17:00:00  146.279333  1.416790  99149.185000  1.910   5.132
# 2020-05-06 18:00:00  126.373333  1.416782  99160.285000  2.493   7.458
# 2020-05-06 19:00:00  115.848667  1.416693  99190.693333  1.458  10.777
# 2020-05-06 20:00:00   97.193000  1.416746  99246.608333  0.397   3.695
#
#                         NOx      O3  PM10_conc  PM10-2.5_conc  PM2.5_conc  \
# 2020-05-06 16:00:00   5.639  40.473     15.705         11.404       4.303
# 2020-05-06 17:00:00   6.875  40.592     19.672         15.035       4.628
# 2020-05-06 18:00:00   9.555  39.162     21.342         16.181       5.170
# 2020-05-06 19:00:00  12.126  35.057     16.456         11.442       5.010
# 2020-05-06 20:00:00   4.078  38.341     13.062          9.670       3.400
#
#                      Air_Temperature  Relative_Humidity
# 2020-05-06 16:00:00           12.375             27.602
# 2020-05-06 17:00:00           12.848             26.503
# 2020-05-06 18:00:00           12.150             27.662
# 2020-05-06 19:00:00           11.400             28.912
# 2020-05-06 20:00:00           10.556             26.898

# %%
dataframe['NO2-O3[ppb]'] = dataframe['NO2[ppb]'] - dataframe['O3[ppb]']

# %%
dataframe.head()
# Out:
#                      Temperature[degC]  Humidity[percent]  PM1.0[ug/m^3]  \
# 2020-05-06 16:00:00          20.936500          19.845833       1.188333
# 2020-05-06 17:00:00          20.838500          19.497333       1.536667
# 2020-05-06 18:00:00          18.088000          21.523500       1.903333
# 2020-05-06 19:00:00          15.246833          25.020167       2.448333
# 2020-05-06 20:00:00          13.793333          23.878000       0.660000
#
#                      PM2.5[ug/m^3]  PM10.0[ug/m^3]    O3[ppb]     O3[V]  \
# 2020-05-06 16:00:00       2.235000        2.576667  50.088667  1.426638
# 2020-05-06 17:00:00       2.705000        3.088333  49.248667  1.426650
# 2020-05-06 18:00:00       3.203333        3.665000  51.494000  1.426415
# 2020-05-06 19:00:00       3.898333        4.298333  53.309000  1.426180
# 2020-05-06 20:00:00       1.293333        1.510000  50.617667  1.426136
#
#                        NO2[ppb]    NO2[V]  Pressure[Pa]     NO     NO2  \
# 2020-05-06 16:00:00  159.735500  1.416693  99177.978333  1.490   3.941
# 2020-05-06 17:00:00  146.279333  1.416790  99149.185000  1.910   5.132
# 2020-05-06 18:00:00  126.373333  1.416782  99160.285000  2.493   7.458
# 2020-05-06 19:00:00  115.848667  1.416693  99190.693333  1.458  10.777
# 2020-05-06 20:00:00   97.193000  1.416746  99246.608333  0.397   3.695
#
#                         NOx      O3  PM10_conc  PM10-2.5_conc  PM2.5_conc  \
# 2020-05-06 16:00:00   5.639  40.473     15.705         11.404       4.303
# 2020-05-06 17:00:00   6.875  40.592     19.672         15.035       4.628
# 2020-05-06 18:00:00   9.555  39.162     21.342         16.181       5.170
# 2020-05-06 19:00:00  12.126  35.057     16.456         11.442       5.010
# 2020-05-06 20:00:00   4.078  38.341     13.062          9.670       3.400
#
#                      Air_Temperature  Relative_Humidity  NO2-O3[ppb]
# 2020-05-06 16:00:00           12.375             27.602   109.646833
# 2020-05-06 17:00:00           12.848             26.503    97.030667
# 2020-05-06 18:00:00           12.150             27.662    74.879333
# 2020-05-06 19:00:00           11.400             28.912    62.539667
# 2020-05-06 20:00:00           10.556             26.898    46.575333

# %%
# ------------------------------------- BUILD TRAINING AND TEST SETS -------------------------------------
# Split the dataframe into TRAINING and TEST sets
# TRAINING DATA
training_data = drop_values(dataframe, dataframe.index, '2020-05-25 15:00:00', 0)
DATA_train_dataframe = training_data.drop(columns = ['NO2', 'NO', 'NOx'])
DATA_train = DATA_train_dataframe.to_numpy()
target_train = training_data['NO2']
target_train = target_train.to_numpy()
# TESTING DATA
test_data = drop_values(dataframe, dataframe.index, '2020-05-25 16:00:00', 1)
DATA_test_dataframe = test_data.drop(columns = ['NO2', 'NO', 'NOx'])
DATA_test = DATA_test_dataframe.to_numpy()
target_test = test_data['NO2']
target_test = target_test.to_numpy()

DATA_train_dataframe.head()
# Out:
#                      Temperature[degC]  Humidity[percent]  PM1.0[ug/m^3]  \
# 2020-05-06 16:00:00          20.936500          19.845833       1.188333
# 2020-05-06 17:00:00          20.838500          19.497333       1.536667
# 2020-05-06 18:00:00          18.088000          21.523500       1.903333
# 2020-05-06 19:00:00          15.246833          25.020167       2.448333
# 2020-05-06 20:00:00          13.793333          23.878000       0.660000
#
#                      PM2.5[ug/m^3]  PM10.0[ug/m^3]    O3[ppb]     O3[V]  \
# 2020-05-06 16:00:00       2.235000        2.576667  50.088667  1.426638
# 2020-05-06 17:00:00       2.705000        3.088333  49.248667  1.426650
# 2020-05-06 18:00:00       3.203333        3.665000  51.494000  1.426415
# 2020-05-06 19:00:00       3.898333        4.298333  53.309000  1.426180
# 2020-05-06 20:00:00       1.293333        1.510000  50.617667  1.426136
#
#                        NO2[ppb]    NO2[V]  Pressure[Pa]      O3  PM10_conc  \
# 2020-05-06 16:00:00  159.735500  1.416693  99177.978333  40.473     15.705
# 2020-05-06 17:00:00  146.279333  1.416790  99149.185000  40.592     19.672
# 2020-05-06 18:00:00  126.373333  1.416782  99160.285000  39.162     21.342
# 2020-05-06 19:00:00  115.848667  1.416693  99190.693333  35.057     16.456
# 2020-05-06 20:00:00   97.193000  1.416746  99246.608333  38.341     13.062
#
#                      PM10-2.5_conc  PM2.5_conc  Air_Temperature  \
# 2020-05-06 16:00:00         11.404       4.303           12.375
# 2020-05-06 17:00:00         15.035       4.628           12.848
# 2020-05-06 18:00:00         16.181       5.170           12.150
# 2020-05-06 19:00:00         11.442       5.010           11.400
# 2020-05-06 20:00:00          9.670       3.400           10.556
#
#                      Relative_Humidity  NO2-O3[ppb]
# 2020-05-06 16:00:00             27.602   109.646833
# 2020-05-06 17:00:00             26.503    97.030667
# 2020-05-06 18:00:00             27.662    74.879333
# 2020-05-06 19:00:00             28.912    62.539667
# 2020-05-06 20:00:00             26.898    46.575333

# %%
# STANDARDIZE THE DATASET TO HAVE ZERO MEAN AND UNIT VARIANCE
# TRAINING DATA
DATA_train_scaled = preprocessing.scale(DATA_train)
target_train_scaled = preprocessing.scale(target_train)
# TESTING DATA
DATA_test_scaled = preprocessing.scale(DATA_test)
target_test_scaled = preprocessing.scale(target_test)

# %%
DATA_train_scaled_OLS = sm.add_constant(DATA_train_scaled)
model = sm.OLS(target_train_scaled, DATA_train_scaled_OLS).fit()
print(model.summary())

intercept_error = model.bse[0]
model.bse = model.bse[1:]
model.bse = np.append(model.bse, intercept_error)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.898
# Method:                 Least Squares   F-statistic:                     250.7
# Date:                Mon, 15 Jun 2020   Prob (F-statistic):          4.28e-209
# Time:                        17:27:59   Log-Likelihood:                -118.94
# No. Observations:                 456   AIC:                             271.9
# Df Residuals:                     439   BIC:                             342.0
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.324e-12      0.015  -3.55e-10      1.000      -0.029       0.029
# x1            -1.1993      1.072     -1.118      0.264      -3.307       0.908
# x2             1.4208      0.153      9.314      0.000       1.121       1.721
# x3             0.1878      0.154      1.216      0.225      -0.116       0.491
# x4             1.4365      0.304      4.724      0.000       0.839       2.034
# x5            -1.8832      0.252     -7.467      0.000      -2.379      -1.388
# x6             1.3529      0.331      4.090      0.000       0.703       2.003
# x7             7.5135      2.916      2.577      0.010       1.783      13.244
# x8            -0.5620      0.192     -2.934      0.004      -0.939      -0.186
# x9            -4.6062      1.824     -2.525      0.012      -8.192      -1.021
# x10            0.0017      0.018      0.092      0.927      -0.034       0.037
# x11           -1.1507      0.030    -38.255      0.000      -1.210      -1.092
# x12          -48.8194     26.054     -1.874      0.062    -100.025       2.386
# x13           38.6647     20.616      1.875      0.061      -1.853      79.183
# x14           16.0951      8.323      1.934      0.054      -0.263      32.453
# x15           -0.9161      0.138     -6.621      0.000      -1.188      -0.644
# x16           -1.6697      0.135    -12.358      0.000      -1.935      -1.404
# x17           -0.8916      0.275     -3.244      0.001      -1.432      -0.351
# ==============================================================================
# Omnibus:                        9.519   Durbin-Watson:                   0.558
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                9.714
# Skew:                           0.357   Prob(JB):                      0.00777
# Kurtosis:                       3.016   Cond. No.                     1.33e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.49e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# --------------------------- TRAIN THE LINEAR REGRESSION MODEL (STANDARDIZED)---------------------------
lr_scaled = LinearRegression().fit(DATA_train_scaled, target_train_scaled)
print("TRAINING PERFORMANCE:")
print("Test set score: {:0.6f}".format(lr_scaled.score(DATA_train_scaled, target_train_scaled)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(target_train_scaled, lr_scaled.predict(DATA_train_scaled))))
print("TEST PERFROMANCE:")
print("Training set score: {:0.6f}".format(lr_scaled.score(DATA_test_scaled, target_test_scaled)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(target_test_scaled, lr_scaled.predict(DATA_test_scaled))))
for i in range(len(DATA_train_dataframe.columns)):
    print("{}\t(coef_:{:0.4f}, std-error:{:0.4f}, z_score: {:0.4f})".format(DATA_train_dataframe.columns[i], lr_scaled.coef_[i], model.bse[i], lr_scaled.coef_[i]/model.bse[i]))
print('\nIntercept: {}, std-error: {}, z_score: {} '.format(lr_scaled.intercept_, intercept_error, lr_scaled.intercept_/intercept_error))
# Out:
# TRAINING PERFORMANCE:
# Test set score: 0.901351
# MAE: 0.2524
#
# TEST PERFROMANCE:
# Training set score: -66.804581
# MAE: 6.0825
#
# Temperature[degC]	(coef_:-1.1993, std-error:1.0724, z_score: -1.1184)
# Humidity[percent]	(coef_:1.4208, std-error:0.1526, z_score: 9.3137)
# PM1.0[ug/m^3]	(coef_:0.1878, std-error:0.1545, z_score: 1.2158)
# PM2.5[ug/m^3]	(coef_:1.4365, std-error:0.3041, z_score: 4.7242)
# PM10.0[ug/m^3]	(coef_:-1.8832, std-error:0.2522, z_score: -7.4671)
# O3[ppb]	(coef_:1.3529, std-error:0.3308, z_score: 4.0898)
# O3[V]	(coef_:7.5135, std-error:2.9157, z_score: 2.5769)
# NO2[ppb]	(coef_:-0.5620, std-error:0.1916, z_score: -2.9341)
# NO2[V]	(coef_:-4.6062, std-error:1.8243, z_score: -2.5249)
# Pressure[Pa]	(coef_:0.0017, std-error:0.0182, z_score: 0.0918)
# O3	(coef_:-1.1507, std-error:0.0301, z_score: -38.2547)
# PM10_conc	(coef_:-48.8194, std-error:26.0536, z_score: -1.8738)
# PM10-2.5_conc	(coef_:38.6647, std-error:20.6159, z_score: 1.8755)
# PM2.5_conc	(coef_:16.0951, std-error:8.3230, z_score: 1.9338)
# Air_Temperature	(coef_:-0.9161, std-error:0.1384, z_score: -6.6206)
# Relative_Humidity	(coef_:-1.6697, std-error:0.1351, z_score: -12.3580)
# NO2-O3[ppb]	(coef_:-0.8916, std-error:0.2749, z_score: -3.2438)
#
# Intercept: -5.325128767066437e-12, std-error: 0.014990399850068805, z_score: -3.552359390228003e-10

# %%
# ------------------------------------- BUILD TRAINING AND TEST SETS -------------------------------------
# Split the dataframe into TRAINING and TEST sets
# TRAINING DATA
training_data = drop_values(dataframe, dataframe.index, '2020-05-25 15:00:00', 0)
DATA_train_dataframe = training_data.drop(columns = ['NO2', 'NO', 'NOx', 
                                                     'PM2.5[ug/m^3]', 'PM10.0[ug/m^3]',
                                                     'O3[ppb]', 'O3[V]', 'NO2[ppb]', 'NO2[V]', 'O3', 'Air_Temperature', 'Relative_Humidity'])
DATA_train = DATA_train_dataframe.to_numpy()
target_train = training_data['NO2']
target_train = target_train.to_numpy()
# TESTING DATA
test_data = drop_values(dataframe, dataframe.index, '2020-05-25 16:00:00', 1)
DATA_test_dataframe = test_data.drop(columns = ['NO2', 'NO', 'NOx', 
                                                'PM2.5[ug/m^3]', 'PM10.0[ug/m^3]',
                                                'O3[ppb]', 'O3[V]', 'NO2[ppb]', 'NO2[V]', 'O3', 'Air_Temperature', 'Relative_Humidity'])
DATA_test = DATA_test_dataframe.to_numpy()
target_test = test_data['NO2']
target_test = target_test.to_numpy()

DATA_train_dataframe.head()
# Out:
#                      Temperature[degC]  Humidity[percent]  PM1.0[ug/m^3]  \
# 2020-05-06 16:00:00          20.936500          19.845833       1.188333
# 2020-05-06 17:00:00          20.838500          19.497333       1.536667
# 2020-05-06 18:00:00          18.088000          21.523500       1.903333
# 2020-05-06 19:00:00          15.246833          25.020167       2.448333
# 2020-05-06 20:00:00          13.793333          23.878000       0.660000
#
#                      Pressure[Pa]  PM10_conc  PM10-2.5_conc  PM2.5_conc
# 2020-05-06 16:00:00  99177.978333     15.705         11.404       4.303
# 2020-05-06 17:00:00  99149.185000     19.672         15.035       4.628
# 2020-05-06 18:00:00  99160.285000     21.342         16.181       5.170
# 2020-05-06 19:00:00  99190.693333     16.456         11.442       5.010
# 2020-05-06 20:00:00  99246.608333     13.062          9.670       3.400

# %%
# STANDARDIZE THE DATASET TO HAVE ZERO MEAN AND UNIT VARIANCE
# TRAINING DATA
DATA_train_scaled = preprocessing.scale(DATA_train)
target_train_scaled = preprocessing.scale(target_train)
# TESTING DATA
DATA_test_scaled = preprocessing.scale(DATA_test)
target_test_scaled = preprocessing.scale(target_test)

# %%
# Split the dataset into TRAINING and TESTING sets
train_dataset = drop_values(dataframe, dataframe.index, '2020-05-25 15:00:00', 0)
train_dataset = train_dataset.drop(columns=['NO', 'NOx', 
                                            'PM10_conc', 'PM10-2.5_conc','PM2.5_conc', 'O3', 
                                            'Air_Temperature', 'Relative_Humidity'])
test_dataset = drop_values(dataframe, dataframe.index, '2020-05-25 16:00:00', 1)
test_dataset = test_dataset.drop(columns=['NO', 'NOx', 
                                          'PM10_conc', 'PM10-2.5_conc','PM2.5_conc','O3', 
                                          'Air_Temperature', 'Relative_Humidity'])
train_stats = train_dataset.describe()
train_stats.pop("NO2")
train_stats = train_stats.transpose()
# Seperate the target values
# TRAINING SET
train_labels = train_dataset.pop('NO2')
# TESTING SET
test_labels = test_dataset.pop('NO2')

# %%
train_dataset
# Out:
#                      Temperature[degC]  Humidity[percent]  PM1.0[ug/m^3]  \
# 2020-05-06 16:00:00          20.936500          19.845833       1.188333
# 2020-05-06 17:00:00          20.838500          19.497333       1.536667
# 2020-05-06 18:00:00          18.088000          21.523500       1.903333
# 2020-05-06 19:00:00          15.246833          25.020167       2.448333
# 2020-05-06 20:00:00          13.793333          23.878000       0.660000
# ...                                ...                ...            ...
# 2020-05-25 11:00:00          40.328500          29.738167       5.068333
# 2020-05-25 12:00:00          40.050000          29.867000       6.316667
# 2020-05-25 13:00:00          36.893167          35.986000      11.150000
# 2020-05-25 14:00:00          35.335167          37.941500      10.685000
# 2020-05-25 15:00:00          36.342921          36.333146       8.542697
#
#                      PM2.5[ug/m^3]  PM10.0[ug/m^3]    O3[ppb]     O3[V]  \
# 2020-05-06 16:00:00       2.235000        2.576667  50.088667  1.426638
# 2020-05-06 17:00:00       2.705000        3.088333  49.248667  1.426650
# 2020-05-06 18:00:00       3.203333        3.665000  51.494000  1.426415
# 2020-05-06 19:00:00       3.898333        4.298333  53.309000  1.426180
# 2020-05-06 20:00:00       1.293333        1.510000  50.617667  1.426136
# ...                            ...             ...        ...       ...
# 2020-05-25 11:00:00       6.813333        7.096667  52.378500  1.428412
# 2020-05-25 12:00:00       8.331667        8.731667  56.984667  1.428279
# 2020-05-25 13:00:00      15.121667       15.691667  63.011667  1.427813
# 2020-05-25 14:00:00      14.855000       15.541667  62.985000  1.427651
# 2020-05-25 15:00:00      11.921348       12.626966  60.447640  1.427813
#
#                        NO2[ppb]    NO2[V]  Pressure[Pa]
# 2020-05-06 16:00:00  159.735500  1.416693  99177.978333
# 2020-05-06 17:00:00  146.279333  1.416790  99149.185000
# 2020-05-06 18:00:00  126.373333  1.416782  99160.285000
# 2020-05-06 19:00:00  115.848667  1.416693  99190.693333
# 2020-05-06 20:00:00   97.193000  1.416746  99246.608333
# ...                         ...       ...           ...
# 2020-05-25 11:00:00  136.823167  1.418727  99727.281667
# 2020-05-25 12:00:00  156.928667  1.418531  99722.440000
# 2020-05-25 13:00:00  146.502500  1.418251  99711.218333
# 2020-05-25 14:00:00  116.277333  1.418314  99697.020000
# 2020-05-25 15:00:00   98.766517  1.418572  99685.743820
#
# [456 rows x 10 columns]

# %%
# Normalize the data
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)

# %%
# --------------------------- TRAIN THE ELASTICNET MODEL ---------------------------
elastic_net = ElasticNet(alpha=0.001, max_iter=1000000).fit(normed_train_data, train_labels)
print("TRAINING PERFORMANCE:")
print("Training set score: {:0.6f}".format(elastic_net.score(normed_train_data, train_labels)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(train_labels, elastic_net.predict(normed_train_data))))
print("TEST PERFROMANCE:")
print("Training set score: {:0.6f}".format(elastic_net.score(normed_test_data, test_labels)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(test_labels, elastic_net.predict(normed_test_data))))
# for i in range(len(DATA_train_dataframe.columns)):
#     print("{}: {}".format(DATA_train_dataframe.columns[i], elastic_net.coef_[i]))
print("\nIntercept:", elastic_net.intercept_)
# Out:
# TRAINING PERFORMANCE:
# Training set score: 0.420549
# MAE: 4.5034
#
# TEST PERFROMANCE:
# Training set score: 0.357420
# MAE: 4.0042
#
#
# Intercept: 9.266263157894782

# %%
# --------------------------- TRAIN THE DECISION TREE MODEL ---------------------------
decision_tree = DecisionTreeRegressor(max_depth=None, min_samples_leaf=1, random_state=0).fit(DATA_train, target_train)
print("TRAINING PERFORMANCE:")
print("Training set score: {:0.6f}".format(decision_tree.score(DATA_train, target_train)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(target_train, decision_tree.predict(DATA_train))))
print("TEST PERFROMANCE:")
print("Training set score: {:0.6f}".format(decision_tree.score(DATA_test, target_test)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(target_test, decision_tree.predict(DATA_test))))
for i in range(len(DATA_train_dataframe.columns)):
    print("{}: {}".format(DATA_train_dataframe.columns[i], decision_tree.feature_importances_[i]))
# Out:
# TRAINING PERFORMANCE:
# Training set score: 1.000000
# MAE: 0.0000
#
# TEST PERFROMANCE:
# Training set score: 0.029964
# MAE: 4.4641
#
# Temperature[degC]: 0.2596049715557136
# Humidity[percent]: 0.029932382062313943
# PM1.0[ug/m^3]: 0.04088964414141677
# Pressure[Pa]: 0.1239159223719058
# PM10_conc: 0.3836262332983617
# PM10-2.5_conc: 0.012109133833652598
# PM2.5_conc: 0.10293992433708121
# NO2-O3[ppb]: 0.046981788399554275

# %%
r = export_text(decision_tree)
print(r)
# Out:
# |--- feature_4 <= 15.68
# |   |--- feature_3 <= 100061.58
# |   |   |--- feature_0 <= 8.94
# |   |   |   |--- feature_3 <= 99863.21
# |   |   |   |   |--- feature_3 <= 99078.19
# |   |   |   |   |   |--- feature_4 <= 7.84
# |   |   |   |   |   |   |--- value: [10.36]
# |   |   |   |   |   |--- feature_4 >  7.84
# |   |   |   |   |   |   |--- feature_6 <= 3.64
# |   |   |   |   |   |   |   |--- feature_2 <= 13.82
# |   |   |   |   |   |   |   |   |--- value: [12.28]
# |   |   |   |   |   |   |   |--- feature_2 >  13.82
# |   |   |   |   |   |   |   |   |--- value: [11.63]
# |   |   |   |   |   |   |--- feature_6 >  3.64
# |   |   |   |   |   |   |   |--- value: [13.04]
# |   |   |   |   |--- feature_3 >  99078.19
# |   |   |   |   |   |--- feature_1 <= 41.53
# |   |   |   |   |   |   |--- feature_6 <= 3.67
# |   |   |   |   |   |   |   |--- feature_1 <= 35.98
# |   |   |   |   |   |   |   |   |--- feature_1 <= 28.20
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 99119.04
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.26]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  99119.04
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.27]
# |   |   |   |   |   |   |   |   |--- feature_1 >  28.20
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 6.02
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 3.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  3.57
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.94]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  6.02
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.22]
# |   |   |   |   |   |   |   |--- feature_1 >  35.98
# |   |   |   |   |   |   |   |   |--- feature_0 <= 5.39
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.54]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.64]
# |   |   |   |   |   |   |   |   |--- feature_0 >  5.39
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 2.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 4.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.39]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  4.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.43]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  2.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 7.29
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.76]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  7.29
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.16]
# |   |   |   |   |   |   |--- feature_6 >  3.67
# |   |   |   |   |   |   |   |--- value: [7.98]
# |   |   |   |   |   |--- feature_1 >  41.53
# |   |   |   |   |   |   |--- feature_2 <= 4.64
# |   |   |   |   |   |   |   |--- feature_6 <= 3.27
# |   |   |   |   |   |   |   |   |--- feature_7 <= 48.24
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.11]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [6.64]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 2.51
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  2.51
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_7 >  48.24
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 2.76
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.63]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  2.76
# |   |   |   |   |   |   |   |   |   |   |--- value: [8.79]
# |   |   |   |   |   |   |   |--- feature_6 >  3.27
# |   |   |   |   |   |   |   |   |--- feature_3 <= 99732.69
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 5.06
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 3.81
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  3.81
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [7.35]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  5.06
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 4.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  4.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [10.53]
# |   |   |   |   |   |   |   |   |--- feature_3 >  99732.69
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 99822.62
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.89]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  99822.62
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.09]
# |   |   |   |   |   |   |--- feature_2 >  4.64
# |   |   |   |   |   |   |   |--- feature_7 <= 33.25
# |   |   |   |   |   |   |   |   |--- feature_6 <= 3.24
# |   |   |   |   |   |   |   |   |   |--- value: [5.52]
# |   |   |   |   |   |   |   |   |--- feature_6 >  3.24
# |   |   |   |   |   |   |   |   |   |--- value: [5.79]
# |   |   |   |   |   |   |   |--- feature_7 >  33.25
# |   |   |   |   |   |   |   |   |--- feature_4 <= 8.71
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 99283.41
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 44.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  44.78
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.69]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  99283.41
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 8.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  8.25
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.57]
# |   |   |   |   |   |   |   |   |--- feature_4 >  8.71
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 15.71
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.87]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  15.71
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.36]
# |   |   |   |--- feature_3 >  99863.21
# |   |   |   |   |--- feature_7 <= 48.38
# |   |   |   |   |   |--- feature_2 <= 6.40
# |   |   |   |   |   |   |--- value: [7.90]
# |   |   |   |   |   |--- feature_2 >  6.40
# |   |   |   |   |   |   |--- value: [7.66]
# |   |   |   |   |--- feature_7 >  48.38
# |   |   |   |   |   |--- feature_1 <= 51.42
# |   |   |   |   |   |   |--- feature_4 <= 12.09
# |   |   |   |   |   |   |   |--- feature_7 <= 55.88
# |   |   |   |   |   |   |   |   |--- value: [15.48]
# |   |   |   |   |   |   |   |--- feature_7 >  55.88
# |   |   |   |   |   |   |   |   |--- value: [16.65]
# |   |   |   |   |   |   |--- feature_4 >  12.09
# |   |   |   |   |   |   |   |--- value: [13.94]
# |   |   |   |   |   |--- feature_1 >  51.42
# |   |   |   |   |   |   |--- feature_4 <= 8.31
# |   |   |   |   |   |   |   |--- value: [10.36]
# |   |   |   |   |   |   |--- feature_4 >  8.31
# |   |   |   |   |   |   |   |--- feature_4 <= 8.80
# |   |   |   |   |   |   |   |   |--- value: [12.80]
# |   |   |   |   |   |   |   |--- feature_4 >  8.80
# |   |   |   |   |   |   |   |   |--- value: [13.88]
# |   |   |--- feature_0 >  8.94
# |   |   |   |--- feature_6 <= 2.91
# |   |   |   |   |--- feature_1 <= 53.06
# |   |   |   |   |   |--- feature_6 <= 2.76
# |   |   |   |   |   |   |--- feature_6 <= 1.36
# |   |   |   |   |   |   |   |--- value: [2.30]
# |   |   |   |   |   |   |--- feature_6 >  1.36
# |   |   |   |   |   |   |   |--- feature_3 <= 99367.82
# |   |   |   |   |   |   |   |   |--- feature_6 <= 2.35
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 14.29
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 99006.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  99006.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  14.29
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.44]
# |   |   |   |   |   |   |   |   |--- feature_6 >  2.35
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 8.60
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 5.63
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.48]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  5.63
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.53]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  8.60
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.34]
# |   |   |   |   |   |   |   |--- feature_3 >  99367.82
# |   |   |   |   |   |   |   |   |--- feature_7 <= 44.07
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 99423.67
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 36.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  36.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.35]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  99423.67
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 14.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  14.30
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.29]
# |   |   |   |   |   |   |   |   |--- feature_7 >  44.07
# |   |   |   |   |   |   |   |   |   |--- value: [1.82]
# |   |   |   |   |   |--- feature_6 >  2.76
# |   |   |   |   |   |   |--- feature_7 <= 37.40
# |   |   |   |   |   |   |   |--- value: [3.03]
# |   |   |   |   |   |   |--- feature_7 >  37.40
# |   |   |   |   |   |   |   |--- value: [2.43]
# |   |   |   |   |--- feature_1 >  53.06
# |   |   |   |   |   |--- feature_0 <= 16.05
# |   |   |   |   |   |   |--- value: [5.14]
# |   |   |   |   |   |--- feature_0 >  16.05
# |   |   |   |   |   |   |--- feature_0 <= 17.66
# |   |   |   |   |   |   |   |--- value: [3.89]
# |   |   |   |   |   |   |--- feature_0 >  17.66
# |   |   |   |   |   |   |   |--- feature_0 <= 18.99
# |   |   |   |   |   |   |   |   |--- value: [3.22]
# |   |   |   |   |   |   |   |--- feature_0 >  18.99
# |   |   |   |   |   |   |   |   |--- value: [3.19]
# |   |   |   |--- feature_6 >  2.91
# |   |   |   |   |--- feature_1 <= 44.04
# |   |   |   |   |   |--- feature_0 <= 9.90
# |   |   |   |   |   |   |--- feature_6 <= 3.69
# |   |   |   |   |   |   |   |--- feature_2 <= 2.06
# |   |   |   |   |   |   |   |   |--- value: [6.61]
# |   |   |   |   |   |   |   |--- feature_2 >  2.06
# |   |   |   |   |   |   |   |   |--- value: [6.56]
# |   |   |   |   |   |   |--- feature_6 >  3.69
# |   |   |   |   |   |   |   |--- value: [8.11]
# |   |   |   |   |   |--- feature_0 >  9.90
# |   |   |   |   |   |   |--- feature_4 <= 14.45
# |   |   |   |   |   |   |   |--- feature_6 <= 3.43
# |   |   |   |   |   |   |   |   |--- feature_0 <= 10.81
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 99423.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.94]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  99423.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [5.31]
# |   |   |   |   |   |   |   |   |--- feature_0 >  10.81
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 11.72
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.67
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.48]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  11.72
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.69]
# |   |   |   |   |   |   |   |--- feature_6 >  3.43
# |   |   |   |   |   |   |   |   |--- feature_5 <= 5.90
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 43.27
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 3.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  3.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  43.27
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.54]
# |   |   |   |   |   |   |   |   |--- feature_5 >  5.90
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 33.43
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.16
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  33.43
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.60]
# |   |   |   |   |   |   |--- feature_4 >  14.45
# |   |   |   |   |   |   |   |--- feature_3 <= 99734.36
# |   |   |   |   |   |   |   |   |--- feature_7 <= 22.34
# |   |   |   |   |   |   |   |   |   |--- value: [1.98]
# |   |   |   |   |   |   |   |   |--- feature_7 >  22.34
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 4.11
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.33]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  4.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 34.12
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.97]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  34.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_3 >  99734.36
# |   |   |   |   |   |   |   |   |--- feature_4 <= 15.20
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 4.94
# |   |   |   |   |   |   |   |   |   |   |--- value: [5.25]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  4.94
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.82]
# |   |   |   |   |   |   |   |   |--- feature_4 >  15.20
# |   |   |   |   |   |   |   |   |   |--- value: [6.42]
# |   |   |   |   |--- feature_1 >  44.04
# |   |   |   |   |   |--- feature_4 <= 11.05
# |   |   |   |   |   |   |--- feature_3 <= 100037.29
# |   |   |   |   |   |   |   |--- feature_1 <= 70.93
# |   |   |   |   |   |   |   |   |--- feature_1 <= 68.07
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 99449.22
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 16.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  16.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  99449.22
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 3.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  3.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_1 >  68.07
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2.57
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 62.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  62.38
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.49]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2.57
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 54.32
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.67]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  54.32
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.20]
# |   |   |   |   |   |   |   |--- feature_1 >  70.93
# |   |   |   |   |   |   |   |   |--- feature_5 <= 1.88
# |   |   |   |   |   |   |   |   |   |--- value: [6.33]
# |   |   |   |   |   |   |   |   |--- feature_5 >  1.88
# |   |   |   |   |   |   |   |   |   |--- value: [7.76]
# |   |   |   |   |   |   |--- feature_3 >  100037.29
# |   |   |   |   |   |   |   |--- feature_3 <= 100054.79
# |   |   |   |   |   |   |   |   |--- feature_2 <= 3.27
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 4.39
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.14]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  4.39
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.58]
# |   |   |   |   |   |   |   |   |--- feature_2 >  3.27
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.85
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.65]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.85
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 4.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  4.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_3 >  100054.79
# |   |   |   |   |   |   |   |   |--- value: [2.31]
# |   |   |   |   |   |--- feature_4 >  11.05
# |   |   |   |   |   |   |--- feature_0 <= 23.85
# |   |   |   |   |   |   |   |--- feature_0 <= 22.04
# |   |   |   |   |   |   |   |   |--- value: [10.15]
# |   |   |   |   |   |   |   |--- feature_0 >  22.04
# |   |   |   |   |   |   |   |   |--- value: [13.67]
# |   |   |   |   |   |   |--- feature_0 >  23.85
# |   |   |   |   |   |   |   |--- feature_6 <= 5.50
# |   |   |   |   |   |   |   |   |--- value: [6.59]
# |   |   |   |   |   |   |   |--- feature_6 >  5.50
# |   |   |   |   |   |   |   |   |--- value: [4.28]
# |   |--- feature_3 >  100061.58
# |   |   |--- feature_0 <= 18.33
# |   |   |   |--- feature_7 <= 14.48
# |   |   |   |   |--- feature_3 <= 100355.25
# |   |   |   |   |   |--- feature_7 <= 13.21
# |   |   |   |   |   |   |--- value: [33.12]
# |   |   |   |   |   |--- feature_7 >  13.21
# |   |   |   |   |   |   |--- value: [35.70]
# |   |   |   |   |--- feature_3 >  100355.25
# |   |   |   |   |   |--- feature_0 <= 15.00
# |   |   |   |   |   |   |--- feature_1 <= 40.62
# |   |   |   |   |   |   |   |--- feature_5 <= 6.60
# |   |   |   |   |   |   |   |   |--- value: [11.74]
# |   |   |   |   |   |   |   |--- feature_5 >  6.60
# |   |   |   |   |   |   |   |   |--- value: [11.03]
# |   |   |   |   |   |   |--- feature_1 >  40.62
# |   |   |   |   |   |   |   |--- value: [15.32]
# |   |   |   |   |   |--- feature_0 >  15.00
# |   |   |   |   |   |   |--- value: [19.78]
# |   |   |   |--- feature_7 >  14.48
# |   |   |   |   |--- feature_6 <= 5.04
# |   |   |   |   |   |--- feature_0 <= 3.60
# |   |   |   |   |   |   |--- feature_2 <= 10.41
# |   |   |   |   |   |   |   |--- feature_5 <= 4.55
# |   |   |   |   |   |   |   |   |--- value: [16.52]
# |   |   |   |   |   |   |   |--- feature_5 >  4.55
# |   |   |   |   |   |   |   |   |--- feature_0 <= 2.83
# |   |   |   |   |   |   |   |   |   |--- value: [15.85]
# |   |   |   |   |   |   |   |   |--- feature_0 >  2.83
# |   |   |   |   |   |   |   |   |   |--- value: [15.61]
# |   |   |   |   |   |   |--- feature_2 >  10.41
# |   |   |   |   |   |   |   |--- value: [11.99]
# |   |   |   |   |   |--- feature_0 >  3.60
# |   |   |   |   |   |   |--- feature_7 <= 30.79
# |   |   |   |   |   |   |   |--- feature_3 <= 100315.02
# |   |   |   |   |   |   |   |   |--- feature_2 <= 6.66
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 3.93
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.21]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  3.93
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 24.74
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.74]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  24.74
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.29]
# |   |   |   |   |   |   |   |   |--- feature_2 >  6.66
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 17.72
# |   |   |   |   |   |   |   |   |   |   |--- value: [5.64]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  17.72
# |   |   |   |   |   |   |   |   |   |   |--- value: [5.89]
# |   |   |   |   |   |   |   |--- feature_3 >  100315.02
# |   |   |   |   |   |   |   |   |--- feature_1 <= 38.17
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 4.30
# |   |   |   |   |   |   |   |   |   |   |--- value: [7.06]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  4.30
# |   |   |   |   |   |   |   |   |   |   |--- value: [7.58]
# |   |   |   |   |   |   |   |   |--- feature_1 >  38.17
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 39.80
# |   |   |   |   |   |   |   |   |   |   |--- value: [5.93]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  39.80
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 2.60
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [6.59]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  2.60
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [6.68]
# |   |   |   |   |   |   |--- feature_7 >  30.79
# |   |   |   |   |   |   |   |--- feature_3 <= 100158.16
# |   |   |   |   |   |   |   |   |--- feature_0 <= 13.14
# |   |   |   |   |   |   |   |   |   |--- value: [4.02]
# |   |   |   |   |   |   |   |   |--- feature_0 >  13.14
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 100107.62
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.12
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.30]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  100107.62
# |   |   |   |   |   |   |   |   |   |   |--- value: [9.59]
# |   |   |   |   |   |   |   |--- feature_3 >  100158.16
# |   |   |   |   |   |   |   |   |--- feature_7 <= 47.89
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 33.25
# |   |   |   |   |   |   |   |   |   |   |--- value: [7.58]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  33.25
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 39.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [10.24]
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  39.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [9.12]
# |   |   |   |   |   |   |   |   |--- feature_7 >  47.89
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 50.54
# |   |   |   |   |   |   |   |   |   |   |--- value: [12.98]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  50.54
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 33.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  33.98
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [11.14]
# |   |   |   |   |--- feature_6 >  5.04
# |   |   |   |   |   |--- feature_2 <= 6.11
# |   |   |   |   |   |   |--- feature_3 <= 100426.54
# |   |   |   |   |   |   |   |--- feature_7 <= 32.04
# |   |   |   |   |   |   |   |   |--- feature_1 <= 51.35
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.75
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 16.47
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.66]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  16.47
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [9.56]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.75
# |   |   |   |   |   |   |   |   |   |   |--- value: [11.78]
# |   |   |   |   |   |   |   |   |--- feature_1 >  51.35
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 53.22
# |   |   |   |   |   |   |   |   |   |   |--- value: [5.88]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  53.22
# |   |   |   |   |   |   |   |   |   |   |--- value: [6.22]
# |   |   |   |   |   |   |   |--- feature_7 >  32.04
# |   |   |   |   |   |   |   |   |--- feature_7 <= 45.19
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 16.99
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 6.66
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [11.20]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  6.66
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [11.10]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  16.99
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.11]
# |   |   |   |   |   |   |   |   |--- feature_7 >  45.19
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 55.81
# |   |   |   |   |   |   |   |   |   |   |--- value: [12.55]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  55.81
# |   |   |   |   |   |   |   |   |   |   |--- value: [12.36]
# |   |   |   |   |   |   |--- feature_3 >  100426.54
# |   |   |   |   |   |   |   |--- feature_1 <= 36.83
# |   |   |   |   |   |   |   |   |--- feature_6 <= 5.80
# |   |   |   |   |   |   |   |   |   |--- value: [12.44]
# |   |   |   |   |   |   |   |   |--- feature_6 >  5.80
# |   |   |   |   |   |   |   |   |   |--- value: [11.43]
# |   |   |   |   |   |   |   |--- feature_1 >  36.83
# |   |   |   |   |   |   |   |   |--- feature_0 <= 15.92
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 22.76
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.14
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [15.10]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.14
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [15.31]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  22.76
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 12.38
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [14.35]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  12.38
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [14.45]
# |   |   |   |   |   |   |   |   |--- feature_0 >  15.92
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 3.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [12.98]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  3.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.17]
# |   |   |   |   |   |--- feature_2 >  6.11
# |   |   |   |   |   |   |--- feature_5 <= 4.63
# |   |   |   |   |   |   |   |--- feature_5 <= 3.80
# |   |   |   |   |   |   |   |   |--- value: [9.96]
# |   |   |   |   |   |   |   |--- feature_5 >  3.80
# |   |   |   |   |   |   |   |   |--- feature_0 <= 11.56
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 11.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 4.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [13.88]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  4.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [14.35]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  11.35
# |   |   |   |   |   |   |   |   |   |   |--- value: [15.52]
# |   |   |   |   |   |   |   |   |--- feature_0 >  11.56
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 12.02
# |   |   |   |   |   |   |   |   |   |   |--- value: [12.50]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  12.02
# |   |   |   |   |   |   |   |   |   |   |--- value: [12.44]
# |   |   |   |   |   |   |--- feature_5 >  4.63
# |   |   |   |   |   |   |   |--- feature_0 <= 16.07
# |   |   |   |   |   |   |   |   |--- feature_6 <= 7.92
# |   |   |   |   |   |   |   |   |   |--- value: [22.41]
# |   |   |   |   |   |   |   |   |--- feature_6 >  7.92
# |   |   |   |   |   |   |   |   |   |--- value: [21.76]
# |   |   |   |   |   |   |   |--- feature_0 >  16.07
# |   |   |   |   |   |   |   |   |--- value: [17.70]
# |   |   |--- feature_0 >  18.33
# |   |   |   |--- feature_7 <= 22.64
# |   |   |   |   |--- feature_3 <= 100340.82
# |   |   |   |   |   |--- feature_1 <= 18.62
# |   |   |   |   |   |   |--- value: [18.20]
# |   |   |   |   |   |--- feature_1 >  18.62
# |   |   |   |   |   |   |--- value: [14.20]
# |   |   |   |   |--- feature_3 >  100340.82
# |   |   |   |   |   |--- feature_0 <= 19.16
# |   |   |   |   |   |   |--- value: [9.27]
# |   |   |   |   |   |--- feature_0 >  19.16
# |   |   |   |   |   |   |--- value: [4.91]
# |   |   |   |--- feature_7 >  22.64
# |   |   |   |   |--- feature_4 <= 12.07
# |   |   |   |   |   |--- feature_0 <= 24.72
# |   |   |   |   |   |   |--- feature_1 <= 40.28
# |   |   |   |   |   |   |   |--- feature_4 <= 11.03
# |   |   |   |   |   |   |   |   |--- feature_5 <= 5.38
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 31.45
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.98]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  31.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 43.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  43.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_5 >  5.38
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.79
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 39.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  39.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.79
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.43]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.32]
# |   |   |   |   |   |   |   |--- feature_4 >  11.03
# |   |   |   |   |   |   |   |   |--- feature_4 <= 11.99
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 27.99
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 26.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  26.13
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.31]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  27.99
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 5.57
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.04]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  5.57
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.42]
# |   |   |   |   |   |   |   |   |--- feature_4 >  11.99
# |   |   |   |   |   |   |   |   |   |--- value: [1.60]
# |   |   |   |   |   |   |--- feature_1 >  40.28
# |   |   |   |   |   |   |   |--- feature_3 <= 100366.87
# |   |   |   |   |   |   |   |   |--- feature_0 <= 19.92
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 3.27
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 30.28
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.96]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  30.28
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.96]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  3.27
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.72]
# |   |   |   |   |   |   |   |   |--- feature_0 >  19.92
# |   |   |   |   |   |   |   |   |   |--- value: [4.50]
# |   |   |   |   |   |   |   |--- feature_3 >  100366.87
# |   |   |   |   |   |   |   |   |--- value: [5.89]
# |   |   |   |   |   |--- feature_0 >  24.72
# |   |   |   |   |   |   |--- feature_1 <= 17.14
# |   |   |   |   |   |   |   |--- feature_6 <= 3.25
# |   |   |   |   |   |   |   |   |--- feature_5 <= 5.93
# |   |   |   |   |   |   |   |   |   |--- value: [4.98]
# |   |   |   |   |   |   |   |   |--- feature_5 >  5.93
# |   |   |   |   |   |   |   |   |   |--- value: [4.90]
# |   |   |   |   |   |   |   |--- feature_6 >  3.25
# |   |   |   |   |   |   |   |   |--- value: [5.34]
# |   |   |   |   |   |   |--- feature_1 >  17.14
# |   |   |   |   |   |   |   |--- feature_4 <= 11.40
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.84
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 44.86
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 34.16
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  34.16
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.01]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  44.86
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 100259.62
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.10]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  100259.62
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.16]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.84
# |   |   |   |   |   |   |   |   |   |--- value: [4.83]
# |   |   |   |   |   |   |   |--- feature_4 >  11.40
# |   |   |   |   |   |   |   |   |--- value: [3.14]
# |   |   |   |   |--- feature_4 >  12.07
# |   |   |   |   |   |--- feature_7 <= 32.08
# |   |   |   |   |   |   |--- feature_4 <= 13.88
# |   |   |   |   |   |   |   |--- feature_7 <= 26.12
# |   |   |   |   |   |   |   |   |--- value: [7.16]
# |   |   |   |   |   |   |   |--- feature_7 >  26.12
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.99
# |   |   |   |   |   |   |   |   |   |--- value: [9.14]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.99
# |   |   |   |   |   |   |   |   |   |--- value: [9.76]
# |   |   |   |   |   |   |--- feature_4 >  13.88
# |   |   |   |   |   |   |   |--- value: [12.06]
# |   |   |   |   |   |--- feature_7 >  32.08
# |   |   |   |   |   |   |--- feature_0 <= 20.41
# |   |   |   |   |   |   |   |--- feature_4 <= 13.15
# |   |   |   |   |   |   |   |   |--- feature_0 <= 20.01
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 8.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 12.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [6.33]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  12.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [6.41]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  8.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.78
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.67]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.78
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.49]
# |   |   |   |   |   |   |   |   |--- feature_0 >  20.01
# |   |   |   |   |   |   |   |   |   |--- value: [8.02]
# |   |   |   |   |   |   |   |--- feature_4 >  13.15
# |   |   |   |   |   |   |   |   |--- value: [10.69]
# |   |   |   |   |   |   |--- feature_0 >  20.41
# |   |   |   |   |   |   |   |--- feature_4 <= 14.12
# |   |   |   |   |   |   |   |   |--- feature_5 <= 8.40
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.88
# |   |   |   |   |   |   |   |   |   |   |--- value: [5.20]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.88
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 12.81
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.37]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  12.81
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.71]
# |   |   |   |   |   |   |   |   |--- feature_5 >  8.40
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 42.64
# |   |   |   |   |   |   |   |   |   |   |--- value: [6.72]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  42.64
# |   |   |   |   |   |   |   |   |   |   |--- value: [6.63]
# |   |   |   |   |   |   |   |--- feature_4 >  14.12
# |   |   |   |   |   |   |   |   |--- feature_7 <= 44.24
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 22.66
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.79]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  22.66
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 7.53
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.68]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  7.53
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.96]
# |   |   |   |   |   |   |   |   |--- feature_7 >  44.24
# |   |   |   |   |   |   |   |   |   |--- value: [5.05]
# |--- feature_4 >  15.68
# |   |--- feature_0 <= 14.24
# |   |   |--- feature_4 <= 18.79
# |   |   |   |--- feature_3 <= 100574.28
# |   |   |   |   |--- feature_7 <= 36.87
# |   |   |   |   |   |--- feature_1 <= 55.53
# |   |   |   |   |   |   |--- feature_1 <= 32.35
# |   |   |   |   |   |   |   |--- feature_5 <= 11.77
# |   |   |   |   |   |   |   |   |--- value: [8.68]
# |   |   |   |   |   |   |   |--- feature_5 >  11.77
# |   |   |   |   |   |   |   |   |--- value: [9.64]
# |   |   |   |   |   |   |--- feature_1 >  32.35
# |   |   |   |   |   |   |   |--- feature_5 <= 9.52
# |   |   |   |   |   |   |   |   |--- value: [6.04]
# |   |   |   |   |   |   |   |--- feature_5 >  9.52
# |   |   |   |   |   |   |   |   |--- value: [7.65]
# |   |   |   |   |   |--- feature_1 >  55.53
# |   |   |   |   |   |   |--- feature_5 <= 7.88
# |   |   |   |   |   |   |   |--- feature_1 <= 65.36
# |   |   |   |   |   |   |   |   |--- value: [12.41]
# |   |   |   |   |   |   |   |--- feature_1 >  65.36
# |   |   |   |   |   |   |   |   |--- value: [11.89]
# |   |   |   |   |   |   |--- feature_5 >  7.88
# |   |   |   |   |   |   |   |--- value: [12.94]
# |   |   |   |   |--- feature_7 >  36.87
# |   |   |   |   |   |--- value: [19.49]
# |   |   |   |--- feature_3 >  100574.28
# |   |   |   |   |--- feature_3 <= 100598.46
# |   |   |   |   |   |--- value: [20.16]
# |   |   |   |   |--- feature_3 >  100598.46
# |   |   |   |   |   |--- feature_4 <= 16.48
# |   |   |   |   |   |   |--- value: [29.73]
# |   |   |   |   |   |--- feature_4 >  16.48
# |   |   |   |   |   |   |--- value: [26.83]
# |   |   |--- feature_4 >  18.79
# |   |   |   |--- feature_2 <= 4.11
# |   |   |   |   |--- feature_6 <= 7.52
# |   |   |   |   |   |--- value: [16.73]
# |   |   |   |   |--- feature_6 >  7.52
# |   |   |   |   |   |--- value: [6.34]
# |   |   |   |--- feature_2 >  4.11
# |   |   |   |   |--- feature_6 <= 7.32
# |   |   |   |   |   |--- feature_4 <= 19.48
# |   |   |   |   |   |   |--- value: [39.38]
# |   |   |   |   |   |--- feature_4 >  19.48
# |   |   |   |   |   |   |--- feature_4 <= 20.10
# |   |   |   |   |   |   |   |--- value: [45.74]
# |   |   |   |   |   |   |--- feature_4 >  20.10
# |   |   |   |   |   |   |   |--- value: [44.54]
# |   |   |   |   |--- feature_6 >  7.32
# |   |   |   |   |   |--- feature_3 <= 100479.36
# |   |   |   |   |   |   |--- feature_3 <= 99206.46
# |   |   |   |   |   |   |   |--- feature_4 <= 37.97
# |   |   |   |   |   |   |   |   |--- value: [31.25]
# |   |   |   |   |   |   |   |--- feature_4 >  37.97
# |   |   |   |   |   |   |   |   |--- feature_3 <= 99164.13
# |   |   |   |   |   |   |   |   |   |--- value: [35.84]
# |   |   |   |   |   |   |   |   |--- feature_3 >  99164.13
# |   |   |   |   |   |   |   |   |   |--- value: [33.84]
# |   |   |   |   |   |   |--- feature_3 >  99206.46
# |   |   |   |   |   |   |   |--- feature_0 <= 13.55
# |   |   |   |   |   |   |   |   |--- feature_0 <= 8.76
# |   |   |   |   |   |   |   |   |   |--- value: [35.26]
# |   |   |   |   |   |   |   |   |--- feature_0 >  8.76
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 17.73
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 100089.54
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  100089.54
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [35.02]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  17.73
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 12.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  12.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |--- feature_0 >  13.55
# |   |   |   |   |   |   |   |   |--- feature_5 <= 22.27
# |   |   |   |   |   |   |   |   |   |--- value: [31.96]
# |   |   |   |   |   |   |   |   |--- feature_5 >  22.27
# |   |   |   |   |   |   |   |   |   |--- value: [37.30]
# |   |   |   |   |   |--- feature_3 >  100479.36
# |   |   |   |   |   |   |--- feature_6 <= 8.63
# |   |   |   |   |   |   |   |--- value: [38.98]
# |   |   |   |   |   |   |--- feature_6 >  8.63
# |   |   |   |   |   |   |   |--- feature_0 <= 8.84
# |   |   |   |   |   |   |   |   |--- value: [35.89]
# |   |   |   |   |   |   |   |--- feature_0 >  8.84
# |   |   |   |   |   |   |   |   |--- value: [36.67]
# |   |--- feature_0 >  14.24
# |   |   |--- feature_6 <= 11.48
# |   |   |   |--- feature_1 <= 47.70
# |   |   |   |   |--- feature_3 <= 99836.62
# |   |   |   |   |   |--- feature_4 <= 25.55
# |   |   |   |   |   |   |--- feature_7 <= 6.81
# |   |   |   |   |   |   |   |--- feature_1 <= 35.03
# |   |   |   |   |   |   |   |   |--- value: [12.01]
# |   |   |   |   |   |   |   |--- feature_1 >  35.03
# |   |   |   |   |   |   |   |   |--- value: [10.32]
# |   |   |   |   |   |   |--- feature_7 >  6.81
# |   |   |   |   |   |   |   |--- feature_1 <= 44.05
# |   |   |   |   |   |   |   |   |--- feature_0 <= 31.41
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 4.83
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 14.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  14.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  4.83
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 5.09
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [10.78]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  5.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_0 >  31.41
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 39.30
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 16.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  16.28
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [6.07]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  39.30
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 92.19
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  92.19
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.63]
# |   |   |   |   |   |   |   |--- feature_1 >  44.05
# |   |   |   |   |   |   |   |   |--- value: [10.92]
# |   |   |   |   |   |--- feature_4 >  25.55
# |   |   |   |   |   |   |--- feature_0 <= 33.61
# |   |   |   |   |   |   |   |--- feature_4 <= 27.41
# |   |   |   |   |   |   |   |   |--- value: [19.22]
# |   |   |   |   |   |   |   |--- feature_4 >  27.41
# |   |   |   |   |   |   |   |   |--- feature_7 <= 46.95
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 99697.25
# |   |   |   |   |   |   |   |   |   |   |--- value: [12.80]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  99697.25
# |   |   |   |   |   |   |   |   |   |   |--- value: [11.38]
# |   |   |   |   |   |   |   |   |--- feature_7 >  46.95
# |   |   |   |   |   |   |   |   |   |--- value: [15.13]
# |   |   |   |   |   |   |--- feature_0 >  33.61
# |   |   |   |   |   |   |   |--- feature_7 <= 48.85
# |   |   |   |   |   |   |   |   |--- feature_1 <= 27.05
# |   |   |   |   |   |   |   |   |   |--- value: [8.20]
# |   |   |   |   |   |   |   |   |--- feature_1 >  27.05
# |   |   |   |   |   |   |   |   |   |--- value: [10.38]
# |   |   |   |   |   |   |   |--- feature_7 >  48.85
# |   |   |   |   |   |   |   |   |--- feature_5 <= 16.74
# |   |   |   |   |   |   |   |   |   |--- value: [6.12]
# |   |   |   |   |   |   |   |   |--- feature_5 >  16.74
# |   |   |   |   |   |   |   |   |   |--- value: [5.74]
# |   |   |   |   |--- feature_3 >  99836.62
# |   |   |   |   |   |--- feature_6 <= 5.99
# |   |   |   |   |   |   |--- feature_2 <= 2.87
# |   |   |   |   |   |   |   |--- feature_3 <= 100609.31
# |   |   |   |   |   |   |   |   |--- value: [11.13]
# |   |   |   |   |   |   |   |--- feature_3 >  100609.31
# |   |   |   |   |   |   |   |   |--- value: [11.06]
# |   |   |   |   |   |   |--- feature_2 >  2.87
# |   |   |   |   |   |   |   |--- feature_3 <= 100355.01
# |   |   |   |   |   |   |   |   |--- value: [27.56]
# |   |   |   |   |   |   |   |--- feature_3 >  100355.01
# |   |   |   |   |   |   |   |   |--- feature_4 <= 16.82
# |   |   |   |   |   |   |   |   |   |--- value: [18.90]
# |   |   |   |   |   |   |   |   |--- feature_4 >  16.82
# |   |   |   |   |   |   |   |   |   |--- value: [22.50]
# |   |   |   |   |   |--- feature_6 >  5.99
# |   |   |   |   |   |   |--- feature_0 <= 29.29
# |   |   |   |   |   |   |   |--- feature_1 <= 36.25
# |   |   |   |   |   |   |   |   |--- feature_4 <= 16.06
# |   |   |   |   |   |   |   |   |   |--- value: [9.37]
# |   |   |   |   |   |   |   |   |--- feature_4 >  16.06
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 99918.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.71]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  99918.15
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 19.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  19.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_1 >  36.25
# |   |   |   |   |   |   |   |   |--- feature_0 <= 18.05
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 100360.62
# |   |   |   |   |   |   |   |   |   |   |--- value: [14.77]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  100360.62
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.64]
# |   |   |   |   |   |   |   |   |--- feature_0 >  18.05
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 19.71
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 99892.60
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [9.83]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  99892.60
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.41]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  19.71
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 7.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  7.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_0 >  29.29
# |   |   |   |   |   |   |   |--- feature_1 <= 22.40
# |   |   |   |   |   |   |   |   |--- feature_3 <= 99907.77
# |   |   |   |   |   |   |   |   |   |--- value: [14.70]
# |   |   |   |   |   |   |   |   |--- feature_3 >  99907.77
# |   |   |   |   |   |   |   |   |   |--- value: [15.92]
# |   |   |   |   |   |   |   |--- feature_1 >  22.40
# |   |   |   |   |   |   |   |   |--- feature_3 <= 99932.56
# |   |   |   |   |   |   |   |   |   |--- value: [12.82]
# |   |   |   |   |   |   |   |   |--- feature_3 >  99932.56
# |   |   |   |   |   |   |   |   |   |--- value: [13.71]
# |   |   |   |--- feature_1 >  47.70
# |   |   |   |   |--- feature_6 <= 10.54
# |   |   |   |   |   |--- feature_7 <= 77.70
# |   |   |   |   |   |   |--- feature_5 <= 10.31
# |   |   |   |   |   |   |   |--- feature_1 <= 61.96
# |   |   |   |   |   |   |   |   |--- feature_7 <= 51.82
# |   |   |   |   |   |   |   |   |   |--- value: [21.64]
# |   |   |   |   |   |   |   |   |--- feature_7 >  51.82
# |   |   |   |   |   |   |   |   |   |--- value: [19.99]
# |   |   |   |   |   |   |   |--- feature_1 >  61.96
# |   |   |   |   |   |   |   |   |--- feature_2 <= 13.09
# |   |   |   |   |   |   |   |   |   |--- value: [15.89]
# |   |   |   |   |   |   |   |   |--- feature_2 >  13.09
# |   |   |   |   |   |   |   |   |   |--- value: [16.29]
# |   |   |   |   |   |   |--- feature_5 >  10.31
# |   |   |   |   |   |   |   |--- feature_3 <= 99433.10
# |   |   |   |   |   |   |   |   |--- value: [8.60]
# |   |   |   |   |   |   |   |--- feature_3 >  99433.10
# |   |   |   |   |   |   |   |   |--- feature_7 <= 47.55
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 28.11
# |   |   |   |   |   |   |   |   |   |   |--- value: [14.48]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  28.11
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.84]
# |   |   |   |   |   |   |   |   |--- feature_7 >  47.55
# |   |   |   |   |   |   |   |   |   |--- value: [12.07]
# |   |   |   |   |   |--- feature_7 >  77.70
# |   |   |   |   |   |   |--- feature_5 <= 6.24
# |   |   |   |   |   |   |   |--- value: [5.83]
# |   |   |   |   |   |   |--- feature_5 >  6.24
# |   |   |   |   |   |   |   |--- feature_0 <= 21.60
# |   |   |   |   |   |   |   |   |--- value: [9.83]
# |   |   |   |   |   |   |   |--- feature_0 >  21.60
# |   |   |   |   |   |   |   |   |--- feature_7 <= 85.76
# |   |   |   |   |   |   |   |   |   |--- value: [8.67]
# |   |   |   |   |   |   |   |   |--- feature_7 >  85.76
# |   |   |   |   |   |   |   |   |   |--- value: [8.31]
# |   |   |   |   |--- feature_6 >  10.54
# |   |   |   |   |   |--- feature_2 <= 11.38
# |   |   |   |   |   |   |--- value: [19.75]
# |   |   |   |   |   |--- feature_2 >  11.38
# |   |   |   |   |   |   |--- value: [30.66]
# |   |   |--- feature_6 >  11.48
# |   |   |   |--- feature_3 <= 99845.40
# |   |   |   |   |--- feature_1 <= 41.90
# |   |   |   |   |   |--- value: [9.84]
# |   |   |   |   |--- feature_1 >  41.90
# |   |   |   |   |   |--- feature_2 <= 15.85
# |   |   |   |   |   |   |--- feature_4 <= 24.51
# |   |   |   |   |   |   |   |--- value: [22.94]
# |   |   |   |   |   |   |--- feature_4 >  24.51
# |   |   |   |   |   |   |   |--- feature_6 <= 13.88
# |   |   |   |   |   |   |   |   |--- feature_6 <= 13.04
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 17.48
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 16.19
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [16.48]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  16.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  17.48
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 50.88
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [19.46]
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  50.88
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [18.46]
# |   |   |   |   |   |   |   |   |--- feature_6 >  13.04
# |   |   |   |   |   |   |   |   |   |--- value: [20.73]
# |   |   |   |   |   |   |   |--- feature_6 >  13.88
# |   |   |   |   |   |   |   |   |--- feature_0 <= 19.37
# |   |   |   |   |   |   |   |   |   |--- value: [15.21]
# |   |   |   |   |   |   |   |   |--- feature_0 >  19.37
# |   |   |   |   |   |   |   |   |   |--- value: [15.95]
# |   |   |   |   |   |--- feature_2 >  15.85
# |   |   |   |   |   |   |--- feature_3 <= 99361.63
# |   |   |   |   |   |   |   |--- feature_6 <= 18.80
# |   |   |   |   |   |   |   |   |--- value: [22.16]
# |   |   |   |   |   |   |   |--- feature_6 >  18.80
# |   |   |   |   |   |   |   |   |--- value: [22.17]
# |   |   |   |   |   |   |--- feature_3 >  99361.63
# |   |   |   |   |   |   |   |--- value: [22.71]
# |   |   |   |--- feature_3 >  99845.40
# |   |   |   |   |--- feature_1 <= 40.29
# |   |   |   |   |   |--- value: [32.41]
# |   |   |   |   |--- feature_1 >  40.29
# |   |   |   |   |   |--- feature_3 <= 99847.93
# |   |   |   |   |   |   |--- value: [27.49]
# |   |   |   |   |   |--- feature_3 >  99847.93
# |   |   |   |   |   |   |--- value: [23.94]

# %%
# Plot the time series graph
plt.figure(figsize=(15,10))
plt.plot(test_data.index.to_series(), elastic_net.predict(normed_test_data), 'o', label="PREDICTED")
plt.plot(test_data.index.to_series(), target_test, 'o', label='AIRPOINTER')
plt.xlabel('Date (YYYY-MM-DD)', fontsize=15)
plt.ylabel('NO2 (ppb)', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate a regression line
xValues = elastic_net.predict(DATA_test)
yValues = target_test
# Calculate a regression line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('EGG/CLUSTER (ppb)', fontsize=25)
plt.ylabel('AIRPOINTER (ppb)', fontsize=25)
plt.legend(loc='best', fontsize=25)

# Calculate the R2 score
metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1)))
# Out:
# 0.33111729169329385

# %%
# Plot the time series graph
plt.figure(figsize=(15,10))
plt.plot(test_data.index.to_series(), decision_tree.predict(DATA_test), 'o', label="PREDICTED")
plt.plot(test_data.index.to_series(), target_test, 'o', label='AIRPOINTER')
plt.xlabel('Date (YYYY-MM-DD)', fontsize=15)
plt.ylabel('NO2 (ppb)', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate a regression line
xValues = decision_tree.predict(DATA_test)
yValues = target_test
# Calculate a regression line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('EGG/CLUSTER (ppb)', fontsize=25)
plt.ylabel('AIRPOINTER (ppb)', fontsize=25)
plt.legend(loc='best', fontsize=25)

# Calculate the R2 score
metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1)))
# Out:
# 0.43177964324342233

# %%
#  ALL EGG PARAMETERS WITH NO2[ppb] and O3[ppb]
# ------------------------------------- BUILD TRAINING AND TEST SETS -------------------------------------
# Split the dataset into TRAINING and TESTING sets
train_dataset = drop_values(dataframe, dataframe.index, '2020-05-25 15:00:00', 0)
train_dataset = train_dataset.drop(columns=['NO', 'NOx', 
                                            'PM10_conc', 'PM10-2.5_conc','PM2.5_conc', 'O3', 
                                            'Air_Temperature', 'Relative_Humidity'])
test_dataset = drop_values(dataframe, dataframe.index, '2020-05-25 16:00:00', 1)
test_dataset = test_dataset.drop(columns=['NO', 'NOx', 
                                          'PM10_conc', 'PM10-2.5_conc','PM2.5_conc','O3', 
                                          'Air_Temperature', 'Relative_Humidity'])
train_stats = train_dataset.describe()
train_stats.pop("NO2")
train_stats = train_stats.transpose()
# Seperate the target values
# TRAINING SET
train_labels = train_dataset.pop('NO2')
# TESTING SET
test_labels = test_dataset.pop('NO2')

train_dataset.head()
# Out:
#                      Temperature[degC]  Humidity[percent]  PM1.0[ug/m^3]  \
# 2020-05-06 16:00:00          20.936500          19.845833       1.188333
# 2020-05-06 17:00:00          20.838500          19.497333       1.536667
# 2020-05-06 18:00:00          18.088000          21.523500       1.903333
# 2020-05-06 19:00:00          15.246833          25.020167       2.448333
# 2020-05-06 20:00:00          13.793333          23.878000       0.660000
#
#                      PM2.5[ug/m^3]  PM10.0[ug/m^3]    O3[ppb]     O3[V]  \
# 2020-05-06 16:00:00       2.235000        2.576667  50.088667  1.426638
# 2020-05-06 17:00:00       2.705000        3.088333  49.248667  1.426650
# 2020-05-06 18:00:00       3.203333        3.665000  51.494000  1.426415
# 2020-05-06 19:00:00       3.898333        4.298333  53.309000  1.426180
# 2020-05-06 20:00:00       1.293333        1.510000  50.617667  1.426136
#
#                        NO2[ppb]    NO2[V]  Pressure[Pa]
# 2020-05-06 16:00:00  159.735500  1.416693  99177.978333
# 2020-05-06 17:00:00  146.279333  1.416790  99149.185000
# 2020-05-06 18:00:00  126.373333  1.416782  99160.285000
# 2020-05-06 19:00:00  115.848667  1.416693  99190.693333
# 2020-05-06 20:00:00   97.193000  1.416746  99246.608333

# %%
# --------------------------------- NORM THE DATASET -------------------------------
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)
# --------------------------- TRAIN THE ELASTICNET MODEL ---------------------------
elastic_net = ElasticNet(alpha=0.001, max_iter=1000000).fit(normed_train_data, train_labels)
print("TRAINING PERFORMANCE:")
print("Training set score: {:0.6f}".format(elastic_net.score(normed_train_data, train_labels)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(train_labels, elastic_net.predict(normed_train_data))))
print("TEST PERFROMANCE:")
print("Training set score: {:0.6f}".format(elastic_net.score(normed_test_data, test_labels)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(test_labels, elastic_net.predict(normed_test_data))))
# for i in range(len(DATA_train_dataframe.columns)):
#     print("{}: {}".format(DATA_train_dataframe.columns[i], elastic_net.coef_[i]))
print("\nIntercept:", elastic_net.intercept_)

# Plot the time series graph
plt.figure(figsize=(15,10))
plt.plot(test_data.index.to_series(), elastic_net.predict(normed_test_data), 'o', label="PREDICTED")
plt.plot(test_data.index.to_series(), target_test, 'o', label='AIRPOINTER')
plt.xlabel('Date (YYYY-MM-DD)', fontsize=15)
plt.ylabel('NO2 (ppb)', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate a regression line
xValues = elastic_net.predict(normed_test_data)
yValues = target_test
# Calculate a regression line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('EGG/CLUSTER (ppb)', fontsize=25)
plt.ylabel('AIRPOINTER (ppb)', fontsize=25)
plt.legend(loc='best', fontsize=25)

# Calculate the R2 score
print("\nR2:", metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1))))
# Out:
# TRAINING PERFORMANCE:
# Training set score: 0.420549
# MAE: 4.5034
#
# TEST PERFROMANCE:
# Training set score: 0.357420
# MAE: 4.0042
#
#
# Intercept: 9.266263157894782
#
# R2: 0.42865097164645294

# %%
#  ALL EGG PARAMETERS WITHOUT NO2[ppb] and O3 [ppb]
# ------------------------------------- BUILD TRAINING AND TEST SETS -------------------------------------
# Split the dataset into TRAINING and TESTING sets
train_dataset = drop_values(dataframe, dataframe.index, '2020-05-25 15:00:00', 0)
train_dataset = train_dataset.drop(columns=['NO', 'NOx', 'NO2[ppb]', 'O3[ppb]', 
                                            'PM10_conc', 'PM10-2.5_conc','PM2.5_conc', 'O3', 
                                            'Air_Temperature', 'Relative_Humidity'])
test_dataset = drop_values(dataframe, dataframe.index, '2020-05-25 16:00:00', 1)
test_dataset = test_dataset.drop(columns=['NO', 'NOx', 'NO2[ppb]', 'O3[ppb]',
                                          'PM10_conc', 'PM10-2.5_conc','PM2.5_conc','O3', 
                                          'Air_Temperature', 'Relative_Humidity'])
train_stats = train_dataset.describe()
train_stats.pop("NO2")
train_stats = train_stats.transpose()
# Seperate the target values
# TRAINING SET
train_labels = train_dataset.pop('NO2')
# TESTING SET
test_labels = test_dataset.pop('NO2')

train_dataset.head()
# Out:
#                      Temperature[degC]  Humidity[percent]  PM1.0[ug/m^3]  \
# 2020-05-06 16:00:00          20.936500          19.845833       1.188333
# 2020-05-06 17:00:00          20.838500          19.497333       1.536667
# 2020-05-06 18:00:00          18.088000          21.523500       1.903333
# 2020-05-06 19:00:00          15.246833          25.020167       2.448333
# 2020-05-06 20:00:00          13.793333          23.878000       0.660000
#
#                      PM2.5[ug/m^3]  PM10.0[ug/m^3]     O3[V]    NO2[V]  \
# 2020-05-06 16:00:00       2.235000        2.576667  1.426638  1.416693
# 2020-05-06 17:00:00       2.705000        3.088333  1.426650  1.416790
# 2020-05-06 18:00:00       3.203333        3.665000  1.426415  1.416782
# 2020-05-06 19:00:00       3.898333        4.298333  1.426180  1.416693
# 2020-05-06 20:00:00       1.293333        1.510000  1.426136  1.416746
#
#                      Pressure[Pa]
# 2020-05-06 16:00:00  99177.978333
# 2020-05-06 17:00:00  99149.185000
# 2020-05-06 18:00:00  99160.285000
# 2020-05-06 19:00:00  99190.693333
# 2020-05-06 20:00:00  99246.608333

# %%
# --------------------------------- NORM THE DATASET -------------------------------
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)
# --------------------------- TRAIN THE ELASTICNET MODEL ---------------------------
elastic_net = ElasticNet(alpha=0.001, max_iter=1000000).fit(normed_train_data, train_labels)
print("TRAINING PERFORMANCE:")
print("Training set score: {:0.6f}".format(elastic_net.score(normed_train_data, train_labels)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(train_labels, elastic_net.predict(normed_train_data))))
print("TEST PERFROMANCE:")
print("Training set score: {:0.6f}".format(elastic_net.score(normed_test_data, test_labels)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(test_labels, elastic_net.predict(normed_test_data))))
# for i in range(len(DATA_train_dataframe.columns)):
#     print("{}: {}".format(DATA_train_dataframe.columns[i], elastic_net.coef_[i]))
print("\nIntercept:", elastic_net.intercept_)

# Plot the time series graph
plt.figure(figsize=(15,10))
plt.plot(test_data.index.to_series(), elastic_net.predict(normed_test_data), 'o', label="PREDICTED")
plt.plot(test_data.index.to_series(), target_test, 'o', label='AIRPOINTER')
plt.xlabel('Date (YYYY-MM-DD)', fontsize=15)
plt.ylabel('NO2 (ppb)', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate a regression line
xValues = elastic_net.predict(normed_test_data)
yValues = target_test
# Calculate a regression line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('EGG/CLUSTER (ppb)', fontsize=25)
plt.ylabel('AIRPOINTER (ppb)', fontsize=25)
plt.legend(loc='best', fontsize=25)

# Calculate the R2 score
print("\nR2:", metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1))))
# Out:
# TRAINING PERFORMANCE:
# Training set score: 0.417923
# MAE: 4.4840
#
# TEST PERFROMANCE:
# Training set score: 0.358987
# MAE: 4.0341
#
#
# Intercept: 9.266263157885428
#
# R2: 0.4272778595394551

# %%
#  TEMP HUMIDITY O3[V] NO2[V] PRESSURE[PA]
# ------------------------------------- BUILD TRAINING AND TEST SETS -------------------------------------
# Split the dataset into TRAINING and TESTING sets
train_dataset = drop_values(dataframe, dataframe.index, '2020-05-25 15:00:00', 0)
train_dataset = train_dataset.drop(columns=['NO', 'NOx', 'NO2[ppb]', 'O3[ppb]',
                                            'PM1.0[ug/m^3]', 'PM2.5[ug/m^3]', 'PM10.0[ug/m^3]',
                                            'PM10_conc', 'PM10-2.5_conc','PM2.5_conc', 'O3', 
                                            'Air_Temperature', 'Relative_Humidity'])
test_dataset = drop_values(dataframe, dataframe.index, '2020-05-25 16:00:00', 1)
test_dataset = test_dataset.drop(columns=['NO', 'NOx','NO2[ppb]', 'O3[ppb]',
                                          'PM1.0[ug/m^3]', 'PM2.5[ug/m^3]', 'PM10.0[ug/m^3]', 
                                          'PM10_conc', 'PM10-2.5_conc','PM2.5_conc','O3', 
                                          'Air_Temperature', 'Relative_Humidity'])
train_stats = train_dataset.describe()
train_stats.pop("NO2")
train_stats = train_stats.transpose()
# Seperate the target values
# TRAINING SET
train_labels = train_dataset.pop('NO2')
# TESTING SET
test_labels = test_dataset.pop('NO2')

train_dataset.head()
# Out:
#                      Temperature[degC]  Humidity[percent]     O3[V]    NO2[V]  \
# 2020-05-06 16:00:00          20.936500          19.845833  1.426638  1.416693
# 2020-05-06 17:00:00          20.838500          19.497333  1.426650  1.416790
# 2020-05-06 18:00:00          18.088000          21.523500  1.426415  1.416782
# 2020-05-06 19:00:00          15.246833          25.020167  1.426180  1.416693
# 2020-05-06 20:00:00          13.793333          23.878000  1.426136  1.416746
#
#                      Pressure[Pa]
# 2020-05-06 16:00:00  99177.978333
# 2020-05-06 17:00:00  99149.185000
# 2020-05-06 18:00:00  99160.285000
# 2020-05-06 19:00:00  99190.693333
# 2020-05-06 20:00:00  99246.608333

# %%
# --------------------------------- NORM THE DATASET -------------------------------
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)
# --------------------------- TRAIN THE ELASTICNET MODEL ---------------------------
elastic_net = ElasticNet(alpha=0.001, max_iter=1000000).fit(normed_train_data, train_labels)
print("TRAINING PERFORMANCE:")
print("Training set score: {:0.6f}".format(elastic_net.score(normed_train_data, train_labels)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(train_labels, elastic_net.predict(normed_train_data))))
print("TEST PERFROMANCE:")
print("Training set score: {:0.6f}".format(elastic_net.score(normed_test_data, test_labels)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(test_labels, elastic_net.predict(normed_test_data))))
# for i in range(len(DATA_train_dataframe.columns)):
#     print("{}: {}".format(DATA_train_dataframe.columns[i], elastic_net.coef_[i]))
print("\nIntercept:", elastic_net.intercept_)

# Plot the time series graph
plt.figure(figsize=(15,10))
plt.plot(test_data.index.to_series(), elastic_net.predict(normed_test_data), 'o', label="PREDICTED")
plt.plot(test_data.index.to_series(), target_test, 'o', label='AIRPOINTER')
plt.xlabel('Date (YYYY-MM-DD)', fontsize=15)
plt.ylabel('NO2 (ppb)', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate a regression line
xValues = elastic_net.predict(normed_test_data)
yValues = target_test
# Calculate a regression line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('EGG/CLUSTER (ppb)', fontsize=25)
plt.ylabel('AIRPOINTER (ppb)', fontsize=25)
plt.legend(loc='best', fontsize=25)

# Calculate the R2 score
print("\nR2:", metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1))))
# Out:
# TRAINING PERFORMANCE:
# Training set score: 0.115413
# MAE: 5.6454
#
# TEST PERFROMANCE:
# Training set score: 0.182812
# MAE: 4.6917
#
#
# Intercept: 9.266263157883808
#
# R2: 0.20096111367769343

# %%
#  ALL EGG PARAMETERS and AIRPOINTER PARAMETERS
# ------------------------------------- BUILD TRAINING AND TEST SETS -------------------------------------
# Split the dataset into TRAINING and TESTING sets
train_dataset = drop_values(dataframe, dataframe.index, '2020-05-25 15:00:00', 0)
train_dataset = train_dataset.drop(columns=['NO', 'NOx'])
test_dataset = drop_values(dataframe, dataframe.index, '2020-05-25 16:00:00', 1)
test_dataset = test_dataset.drop(columns=['NO', 'NOx'])
train_stats = train_dataset.describe()
train_stats.pop("NO2")
train_stats = train_stats.transpose()
# Seperate the target values
# TRAINING SET
train_labels = train_dataset.pop('NO2')
# TESTING SET
test_labels = test_dataset.pop('NO2')

train_dataset.head()
# Out:
#                      Temperature[degC]  Humidity[percent]  PM1.0[ug/m^3]  \
# 2020-05-06 16:00:00          20.936500          19.845833       1.188333
# 2020-05-06 17:00:00          20.838500          19.497333       1.536667
# 2020-05-06 18:00:00          18.088000          21.523500       1.903333
# 2020-05-06 19:00:00          15.246833          25.020167       2.448333
# 2020-05-06 20:00:00          13.793333          23.878000       0.660000
#
#                      PM2.5[ug/m^3]  PM10.0[ug/m^3]    O3[ppb]     O3[V]  \
# 2020-05-06 16:00:00       2.235000        2.576667  50.088667  1.426638
# 2020-05-06 17:00:00       2.705000        3.088333  49.248667  1.426650
# 2020-05-06 18:00:00       3.203333        3.665000  51.494000  1.426415
# 2020-05-06 19:00:00       3.898333        4.298333  53.309000  1.426180
# 2020-05-06 20:00:00       1.293333        1.510000  50.617667  1.426136
#
#                        NO2[ppb]    NO2[V]  Pressure[Pa]      O3  PM10_conc  \
# 2020-05-06 16:00:00  159.735500  1.416693  99177.978333  40.473     15.705
# 2020-05-06 17:00:00  146.279333  1.416790  99149.185000  40.592     19.672
# 2020-05-06 18:00:00  126.373333  1.416782  99160.285000  39.162     21.342
# 2020-05-06 19:00:00  115.848667  1.416693  99190.693333  35.057     16.456
# 2020-05-06 20:00:00   97.193000  1.416746  99246.608333  38.341     13.062
#
#                      PM10-2.5_conc  PM2.5_conc  Air_Temperature  \
# 2020-05-06 16:00:00         11.404       4.303           12.375
# 2020-05-06 17:00:00         15.035       4.628           12.848
# 2020-05-06 18:00:00         16.181       5.170           12.150
# 2020-05-06 19:00:00         11.442       5.010           11.400
# 2020-05-06 20:00:00          9.670       3.400           10.556
#
#                      Relative_Humidity
# 2020-05-06 16:00:00             27.602
# 2020-05-06 17:00:00             26.503
# 2020-05-06 18:00:00             27.662
# 2020-05-06 19:00:00             28.912
# 2020-05-06 20:00:00             26.898

# %%
# --------------------------------- NORM THE DATASET -------------------------------
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)
# --------------------------- TRAIN THE ELASTICNET MODEL ---------------------------
elastic_net = ElasticNet(alpha=0.001, max_iter=1000000).fit(normed_train_data, train_labels)
print("TRAINING PERFORMANCE:")
print("Training set score: {:0.6f}".format(elastic_net.score(normed_train_data, train_labels)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(train_labels, elastic_net.predict(normed_train_data))))
print("TEST PERFROMANCE:")
print("Training set score: {:0.6f}".format(elastic_net.score(normed_test_data, test_labels)))
print('MAE: {:0.4f}\n'.format(metrics.mean_absolute_error(test_labels, elastic_net.predict(normed_test_data))))
# for i in range(len(DATA_train_dataframe.columns)):
#     print("{}: {}".format(DATA_train_dataframe.columns[i], elastic_net.coef_[i]))
print("\nIntercept:", elastic_net.intercept_)

# Plot the time series graph
plt.figure(figsize=(15,10))
plt.plot(test_data.index.to_series(), elastic_net.predict(normed_test_data), 'o', label="PREDICTED")
plt.plot(test_data.index.to_series(), target_test, 'o', label='AIRPOINTER')
plt.xlabel('Date (YYYY-MM-DD)', fontsize=15)
plt.ylabel('NO2 (ppb)', fontsize=15)
plt.legend(loc='best', fontsize=15)

# Calculate a regression line
xValues = elastic_net.predict(normed_test_data)
yValues = target_test
# Calculate a regression line
linear_regression = LinearRegression().fit(xValues.reshape(-1,1), yValues)
# Plot the values graph with the regression line
plt.figure(figsize=(15,10))
plt.plot(xValues, yValues, 'o')
plt.plot(xValues, 
         linear_regression.predict(xValues.reshape(-1,1)),
         label='y= {:0.4f}*x +({:0.4f})'.format(linear_regression.coef_[0], linear_regression.intercept_),
         linewidth=3)
plt.xlabel('EGG/CLUSTER (ppb)', fontsize=25)
plt.ylabel('AIRPOINTER (ppb)', fontsize=25)
plt.legend(loc='best', fontsize=25)

# Calculate the R2 score
print("\nR2:", metrics.r2_score(yValues, linear_regression.predict(xValues.reshape(-1,1))))
# Out:
# TRAINING PERFORMANCE:
# Training set score: 0.898047
# MAE: 2.1257
#
# TEST PERFROMANCE:
# Training set score: 0.345626
# MAE: 4.0736
#
#
# Intercept: 9.266263157901747
#
# R2: 0.46804815567191815
